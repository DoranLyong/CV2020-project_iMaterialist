# %% [markdown]
# # iMaterialist 2020 Tutorial
# * refer to [here](https://www.kaggle.com/kaushal2896/imaterialist-2020-starter-eda-mask-rcnn)

# %%
import sys 
sys.path.append("./trainer/")
print(sys.path)
# Out:
# ['C:\\Users\\camin\\PhD_DB\\CV2020-project_iMaterialist', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\python37.zip', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\DLLs', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env', '', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib\\site-packages', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\win32', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\win32\\lib', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\Pythonwin', 'C:\\Users\\camin\\anaconda3\\envs\\pytorch_env\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\camin\\.ipython', './trainer/']

# %%
import torch 
import torch.nn as nn 
import torch.optim as optim 

from torchvision import datasets, transforms
from torch.optim.lr_scheduler import MultiStepLR

# %%
from PIL import Image, ImageFile
import numpy as np 
import os
import glob 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import pandas as pd 
import json
import gc
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# # Dataloader tutorial
# * [How to show PIL Image in ipython notebook](https://stackoverflow.com/questions/26649716/how-to-show-pil-image-in-ipython-notebook)
# * [Dataloader for semantic segmentation](https://discuss.pytorch.org/t/dataloader-for-semantic-segmentation/48290)

# %%
train_dir = "../imaterialist-fashion-2020-fgvc7/train"
img_files = glob.glob(os.path.join(train_dir, "*.jpg"))

# %%
idx = 0
pil_im = Image.open(img_files[idx])

# %%
# %matplotlib inline 
print("file_name: ", img_files[idx])
plt.imshow(np.asarray(pil_im))
# Out:
# file_name:  ../imaterialist-fashion-2020-fgvc7/train\00000663ed1ff0c4e0132b9b9ac53f6e.jpg

# %% [markdown]
# # 1. Get Training and Validation Data Loader
# * [iMaterialist Detectron2](https://www.kaggle.com/julienbeaulieu/imaterialist-detectron2)

# %%
data_dir = Path("../imaterialist-fashion-2020-fgvc7")
img_dir =  Path("../imaterialist-fashion-2020-fgvc7/train")
train_data = pd.read_csv(data_dir/"train.csv")

# %%
train_data.sample(5)
# Out:
#                                  ImageId  \
# 113936  57729863ad5286d30c4107a17251fce8
# 192931  94c8c58a76caf40e904c39dd013da39f
# 66159   32ea644fa456482b9e5208c0f373502b
# 296246  e3aa70c7ff55593f7f6cbf41d84673d1
# 157165  78a5d811bcea8d9f3af21276554266c4
#
#                                             EncodedPixels  Height  Width  \
# 113936  311692 30 312646 41 313599 53 314553 62 315507...     960    640
# 192931  258544 6 259531 21 260519 34 261513 41 262514 ...    1000    667
# 66159   835528 2 838527 4 841526 7 844525 10 847524 12...    3000   2000
# 296246  5137938 1 5140730 1 5143521 1 5146312 2 514910...    2792   4128
# 157165  218739 3 219711 10 220683 16 221656 21 222628 ...     978    699
#
#         ClassId                    AttributesIds
# 113936       32                              223
# 192931       32                              218
# 66159        31                              160
# 296246       13                              NaN
# 157165       10  113,114,119,141,151,295,304,317

# %%
# _Start: to get label descriptions 
with open(data_dir/"label_descriptions.json", 'r') as file:
    label_desc = json.load(file)
# _End: to get label descriptions

# %%
label_desc
# Out:
# {'categories': [{'id': 0,
#    'name': 'shirt, blouse',
#    'supercategory': 'upperbody',
#    'level': 2},
#   {'id': 1,
#    'name': 'top, t-shirt, sweatshirt',
#    'supercategory': 'upperbody',
#    'level': 2},
#   {'id': 2, 'name': 'sweater', 'supercategory': 'upperbody', 'level': 2},
#   {'id': 3, 'name': 'cardigan', 'supercategory': 'upperbody', 'level': 2},
#   {'id': 4, 'name': 'jacket', 'supercategory': 'upperbody', 'level': 2},
#   {'id': 5, 'name': 'vest', 'supercategory': 'upperbody', 'level': 2},
#   {'id': 6, 'name': 'pants', 'supercategory': 'lowerbody', 'level': 2},
#   {'id': 7, 'name': 'shorts', 'supercategory': 'lowerbody', 'level': 2},
#   {'id': 8, 'name': 'skirt', 'supercategory': 'lowerbody', 'level': 2},
#   {'id': 9, 'name': 'coat', 'supercategory': 'wholebody', 'level': 2},
#   {'id': 10, 'name': 'dress', 'supercategory': 'wholebody', 'level': 2},
#   {'id': 11, 'name': 'jumpsuit', 'supercategory': 'wholebody', 'level': 2},
#   {'id': 12, 'name': 'cape', 'supercategory': 'wholebody', 'level': 2},
#   {'id': 13, 'name': 'glasses', 'supercategory': 'head', 'level': 2},
#   {'id': 14, 'name': 'hat', 'supercategory': 'head', 'level': 2},
#   {'id': 15,
#    'name': 'headband, head covering, hair accessory',
#    'supercategory': 'head',
#    'level': 2},
#   {'id': 16, 'name': 'tie', 'supercategory': 'neck', 'level': 2},
#   {'id': 17, 'name': 'glove', 'supercategory': 'arms and hands', 'level': 2},
#   {'id': 18, 'name': 'watch', 'supercategory': 'arms and hands', 'level': 2},
#   {'id': 19, 'name': 'belt', 'supercategory': 'waist', 'level': 2},
#   {'id': 20,
#    'name': 'leg warmer',
#    'supercategory': 'legs and feet',
#    'level': 2},
#   {'id': 21,
#    'name': 'tights, stockings',
#    'supercategory': 'legs and feet',
#    'level': 2},
#   {'id': 22, 'name': 'sock', 'supercategory': 'legs and feet', 'level': 2},
#   {'id': 23, 'name': 'shoe', 'supercategory': 'legs and feet', 'level': 2},
#   {'id': 24, 'name': 'bag, wallet', 'supercategory': 'others', 'level': 2},
#   {'id': 25, 'name': 'scarf', 'supercategory': 'others', 'level': 2},
#   {'id': 26, 'name': 'umbrella', 'supercategory': 'others', 'level': 2},
#   {'id': 27, 'name': 'hood', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 28, 'name': 'collar', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 29, 'name': 'lapel', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 30,
#    'name': 'epaulette',
#    'supercategory': 'garment parts',
#    'level': 2},
#   {'id': 31, 'name': 'sleeve', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 32, 'name': 'pocket', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 33, 'name': 'neckline', 'supercategory': 'garment parts', 'level': 2},
#   {'id': 34, 'name': 'buckle', 'supercategory': 'closures', 'level': 2},
#   {'id': 35, 'name': 'zipper', 'supercategory': 'closures', 'level': 2},
#   {'id': 36, 'name': 'applique', 'supercategory': 'decorations', 'level': 2},
#   {'id': 37, 'name': 'bead', 'supercategory': 'decorations', 'level': 2},
#   {'id': 38, 'name': 'bow', 'supercategory': 'decorations', 'level': 2},
#   {'id': 39, 'name': 'flower', 'supercategory': 'decorations', 'level': 2},
#   {'id': 40, 'name': 'fringe', 'supercategory': 'decorations', 'level': 2},
#   {'id': 41, 'name': 'ribbon', 'supercategory': 'decorations', 'level': 2},
#   {'id': 42, 'name': 'rivet', 'supercategory': 'decorations', 'level': 2},
#   {'id': 43, 'name': 'ruffle', 'supercategory': 'decorations', 'level': 2},
#   {'id': 44, 'name': 'sequin', 'supercategory': 'decorations', 'level': 2},
#   {'id': 45, 'name': 'tassel', 'supercategory': 'decorations', 'level': 2}],
#  'attributes': [{'id': 0,
#    'name': 'classic (t-shirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 1, 'name': 'polo (shirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 2, 'name': 'undershirt', 'supercategory': 'nickname', 'level': 1},
#   {'id': 3, 'name': 'henley (shirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 4,
#    'name': 'ringer (t-shirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 5,
#    'name': 'raglan (t-shirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 6, 'name': 'rugby (shirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 7, 'name': 'sailor (shirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 8, 'name': 'crop (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 9, 'name': 'halter (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 10, 'name': 'camisole', 'supercategory': 'nickname', 'level': 1},
#   {'id': 11, 'name': 'tank (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 12, 'name': 'peasant (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 13, 'name': 'tube (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 14, 'name': 'tunic (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 15, 'name': 'smock (top)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 16, 'name': 'hoodie', 'supercategory': 'nickname', 'level': 1},
#   {'id': 17, 'name': 'blazer', 'supercategory': 'nickname', 'level': 1},
#   {'id': 18, 'name': 'pea (jacket)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 19,
#    'name': 'puffer (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 20,
#    'name': 'biker (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 21,
#    'name': 'trucker (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 22,
#    'name': 'bomber (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 23, 'name': 'anorak', 'supercategory': 'nickname', 'level': 1},
#   {'id': 24,
#    'name': 'safari (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 25, 'name': 'mao (jacket)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 26,
#    'name': 'nehru (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 27,
#    'name': 'norfolk (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 28,
#    'name': 'classic military (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 29,
#    'name': 'track (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 30, 'name': 'windbreaker', 'supercategory': 'nickname', 'level': 1},
#   {'id': 31,
#    'name': 'chanel (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 32, 'name': 'bolero', 'supercategory': 'nickname', 'level': 1},
#   {'id': 33,
#    'name': 'tuxedo (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 34,
#    'name': 'varsity (jacket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 35, 'name': 'crop (jacket)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 36, 'name': 'jeans', 'supercategory': 'nickname', 'level': 1},
#   {'id': 37, 'name': 'sweatpants', 'supercategory': 'nickname', 'level': 1},
#   {'id': 38, 'name': 'leggings', 'supercategory': 'nickname', 'level': 1},
#   {'id': 39,
#    'name': 'hip-huggers (pants)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 40, 'name': 'cargo (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 41, 'name': 'culottes', 'supercategory': 'nickname', 'level': 1},
#   {'id': 42, 'name': 'capri (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 43, 'name': 'harem (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 44,
#    'name': 'sailor (pants)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 45, 'name': 'jodhpur', 'supercategory': 'nickname', 'level': 1},
#   {'id': 46, 'name': 'peg (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 47, 'name': 'camo (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 48, 'name': 'track (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 49, 'name': 'crop (pants)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 50,
#    'name': 'short (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 51,
#    'name': 'booty (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 52,
#    'name': 'bermuda (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 53,
#    'name': 'cargo (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 54, 'name': 'trunks', 'supercategory': 'nickname', 'level': 1},
#   {'id': 55, 'name': 'boardshorts', 'supercategory': 'nickname', 'level': 1},
#   {'id': 56, 'name': 'skort', 'supercategory': 'nickname', 'level': 1},
#   {'id': 57,
#    'name': 'roll-up (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 58,
#    'name': 'tie-up (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 59,
#    'name': 'culotte (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 60,
#    'name': 'lounge (shorts)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 61, 'name': 'bloomers', 'supercategory': 'nickname', 'level': 1},
#   {'id': 62, 'name': 'tutu (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 63, 'name': 'kilt', 'supercategory': 'nickname', 'level': 1},
#   {'id': 64, 'name': 'wrap (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 65,
#    'name': 'skater (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 66, 'name': 'cargo (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 67,
#    'name': 'hobble (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 68,
#    'name': 'sheath (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 69,
#    'name': 'ball gown (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 70, 'name': 'gypsy (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 71,
#    'name': 'rah-rah (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 72,
#    'name': 'prairie (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 73,
#    'name': 'flamenco (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 74,
#    'name': 'accordion (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 75,
#    'name': 'sarong (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 76, 'name': 'tulip (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 77,
#    'name': 'dirndl (skirt)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 78, 'name': 'godet (skirt)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 79,
#    'name': 'blanket (coat)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 80, 'name': 'parka', 'supercategory': 'nickname', 'level': 1},
#   {'id': 81, 'name': 'trench (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 82, 'name': 'pea (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 83,
#    'name': 'shearling (coat)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 84,
#    'name': 'teddy bear (coat)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 85, 'name': 'puffer (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 86, 'name': 'duster (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 87, 'name': 'raincoat', 'supercategory': 'nickname', 'level': 1},
#   {'id': 88, 'name': 'kimono', 'supercategory': 'nickname', 'level': 1},
#   {'id': 89, 'name': 'robe', 'supercategory': 'nickname', 'level': 1},
#   {'id': 90, 'name': 'dress (coat )', 'supercategory': 'nickname', 'level': 1},
#   {'id': 91, 'name': 'duffle (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 92, 'name': 'wrap (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 93,
#    'name': 'military (coat)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 94, 'name': 'swing (coat)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 95,
#    'name': 'halter (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 96, 'name': 'wrap (dress)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 97,
#    'name': 'chemise (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 98, 'name': 'slip (dress)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 99, 'name': 'cheongsams', 'supercategory': 'nickname', 'level': 1},
#   {'id': 100,
#    'name': 'jumper (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 101,
#    'name': 'shift (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 102,
#    'name': 'sheath (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 103,
#    'name': 'shirt (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 104, 'name': 'sundress', 'supercategory': 'nickname', 'level': 1},
#   {'id': 105, 'name': 'kaftan', 'supercategory': 'nickname', 'level': 1},
#   {'id': 106,
#    'name': 'bodycon (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 107, 'name': 'nightgown', 'supercategory': 'nickname', 'level': 1},
#   {'id': 108, 'name': 'gown', 'supercategory': 'nickname', 'level': 1},
#   {'id': 109,
#    'name': 'sweater (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 110, 'name': 'tea (dress)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 111,
#    'name': 'blouson (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 112,
#    'name': 'tunic (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 113,
#    'name': 'skater (dress)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 114,
#    'name': 'asymmetrical',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 115,
#    'name': 'symmetrical',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 116, 'name': 'peplum', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 117, 'name': 'circle', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 118, 'name': 'flare', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 119,
#    'name': 'fit and flare',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 120, 'name': 'trumpet', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 121, 'name': 'mermaid', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 122, 'name': 'balloon', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 123, 'name': 'bell', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 124,
#    'name': 'bell bottom',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 125, 'name': 'bootcut', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 126, 'name': 'peg', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 127, 'name': 'pencil', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 128, 'name': 'straight', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 129, 'name': 'a-line', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 130, 'name': 'tent', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 131, 'name': 'baggy', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 132, 'name': 'wide leg', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 133, 'name': 'high low', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 134,
#    'name': 'curved (fit)',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 135,
#    'name': 'tight (fit)',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 136,
#    'name': 'regular (fit)',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 137,
#    'name': 'loose (fit)',
#    'supercategory': 'silhouette',
#    'level': 1},
#   {'id': 138, 'name': 'oversized', 'supercategory': 'silhouette', 'level': 1},
#   {'id': 139,
#    'name': 'empire waistline',
#    'supercategory': 'waistline',
#    'level': 1},
#   {'id': 140,
#    'name': 'dropped waistline',
#    'supercategory': 'waistline',
#    'level': 1},
#   {'id': 141, 'name': 'high waist', 'supercategory': 'waistline', 'level': 1},
#   {'id': 142,
#    'name': 'normal waist',
#    'supercategory': 'waistline',
#    'level': 1},
#   {'id': 143, 'name': 'low waist', 'supercategory': 'waistline', 'level': 1},
#   {'id': 144,
#    'name': 'basque (wasitline)',
#    'supercategory': 'waistline',
#    'level': 1},
#   {'id': 145,
#    'name': 'no waistline',
#    'supercategory': 'waistline',
#    'level': 1},
#   {'id': 146,
#    'name': 'above-the-hip (length)',
#    'supercategory': 'length',
#    'level': 1},
#   {'id': 147, 'name': 'hip (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 148, 'name': 'micro (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 149, 'name': 'mini (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 150,
#    'name': 'above-the-knee (length)',
#    'supercategory': 'length',
#    'level': 1},
#   {'id': 151, 'name': 'knee (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 152,
#    'name': 'below the knee (length)',
#    'supercategory': 'length',
#    'level': 1},
#   {'id': 153, 'name': 'midi', 'supercategory': 'length', 'level': 1},
#   {'id': 154, 'name': 'maxi (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 155, 'name': 'floor (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 156, 'name': 'sleeveless', 'supercategory': 'length', 'level': 1},
#   {'id': 157, 'name': 'short (length)', 'supercategory': 'length', 'level': 1},
#   {'id': 158, 'name': 'elbow-length', 'supercategory': 'length', 'level': 1},
#   {'id': 159,
#    'name': 'three quarter (length)',
#    'supercategory': 'length',
#    'level': 1},
#   {'id': 160, 'name': 'wrist-length', 'supercategory': 'length', 'level': 1},
#   {'id': 161,
#    'name': 'asymmetric (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 162,
#    'name': 'regular (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 163,
#    'name': 'shirt (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 164,
#    'name': 'polo (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 165,
#    'name': 'chelsea (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 166,
#    'name': 'banded (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 167,
#    'name': 'mandarin (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 168,
#    'name': 'peter pan (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 169, 'name': 'bow (collar)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 170,
#    'name': 'stand-away (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 171,
#    'name': 'jabot (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 172,
#    'name': 'sailor (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 173,
#    'name': 'oversized (collar)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 174,
#    'name': 'notched (lapel)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 175, 'name': 'peak (lapel)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 176,
#    'name': 'shawl (lapel)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 177,
#    'name': 'napoleon (lapel)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 178,
#    'name': 'oversized (lapel)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 179,
#    'name': 'collarless',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 180,
#    'name': 'asymmetric (neckline)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 181,
#    'name': 'crew (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 182,
#    'name': 'round (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 183, 'name': 'v-neck', 'supercategory': 'neckline type', 'level': 1},
#   {'id': 184,
#    'name': 'surplice (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 185,
#    'name': 'oval (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 186, 'name': 'u-neck', 'supercategory': 'neckline type', 'level': 1},
#   {'id': 187,
#    'name': 'sweetheart (neckline)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 188,
#    'name': 'queen anne (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 189,
#    'name': 'boat (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 190,
#    'name': 'scoop (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 191,
#    'name': 'square (neckline)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 192,
#    'name': 'plunging (neckline)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 193,
#    'name': 'keyhole (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 194,
#    'name': 'halter (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 195,
#    'name': 'crossover (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 196,
#    'name': 'choker (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 197,
#    'name': 'high (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 198,
#    'name': 'turtle (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 199,
#    'name': 'cowl (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 200,
#    'name': 'straight across (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 201,
#    'name': 'illusion (neck)',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 202,
#    'name': 'off-the-shoulder',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 203,
#    'name': 'one shoulder',
#    'supercategory': 'neckline type',
#    'level': 1},
#   {'id': 204,
#    'name': 'set-in sleeve',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 205,
#    'name': 'dropped-shoulder sleeve',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 206,
#    'name': 'raglan (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 207, 'name': 'cap (sleeve)', 'supercategory': 'nickname', 'level': 1},
#   {'id': 208,
#    'name': 'tulip (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 209,
#    'name': 'puff (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 210,
#    'name': 'bell (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 211,
#    'name': 'circular flounce (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 212,
#    'name': 'poet (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 213,
#    'name': 'dolman (sleeve), batwing (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 214,
#    'name': 'bishop (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 215,
#    'name': 'leg of mutton (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 216,
#    'name': 'kimono (sleeve)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 217,
#    'name': 'cargo (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 218,
#    'name': 'patch (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 219,
#    'name': 'welt (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 220,
#    'name': 'kangaroo (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 221,
#    'name': 'seam (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 222,
#    'name': 'slash (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 223,
#    'name': 'curved (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 224,
#    'name': 'flap (pocket)',
#    'supercategory': 'nickname',
#    'level': 1},
#   {'id': 225,
#    'name': 'single breasted',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 226,
#    'name': 'double breasted',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 227, 'name': 'lace up', 'supercategory': 'opening type', 'level': 1},
#   {'id': 228, 'name': 'wrapping', 'supercategory': 'opening type', 'level': 1},
#   {'id': 229, 'name': 'zip-up', 'supercategory': 'opening type', 'level': 1},
#   {'id': 230,
#    'name': 'fly (opening)',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 231,
#    'name': 'chained (opening)',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 232,
#    'name': 'buckled (opening)',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 233,
#    'name': 'toggled (opening)',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 234,
#    'name': 'no opening',
#    'supercategory': 'opening type',
#    'level': 1},
#   {'id': 281,
#    'name': 'plastic',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 282,
#    'name': 'rubber',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 283,
#    'name': 'metal',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 285,
#    'name': 'feather',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 286,
#    'name': 'gem',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 287,
#    'name': 'bone',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 288,
#    'name': 'ivory',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 289,
#    'name': 'fur',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 290, 'name': 'suede', 'supercategory': 'leather', 'level': 2},
#   {'id': 291, 'name': 'shearling', 'supercategory': 'leather', 'level': 2},
#   {'id': 292, 'name': 'crocodile', 'supercategory': 'leather', 'level': 2},
#   {'id': 293, 'name': 'snakeskin', 'supercategory': 'leather', 'level': 2},
#   {'id': 294,
#    'name': 'wood',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 295,
#    'name': 'no non-textile material',
#    'supercategory': 'non-textile material type',
#    'level': 1},
#   {'id': 296,
#    'name': 'burnout',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 297,
#    'name': 'distressed',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 298,
#    'name': 'washed',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 299,
#    'name': 'embossed',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 300,
#    'name': 'frayed',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 301,
#    'name': 'printed',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 302,
#    'name': 'ruched',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 303,
#    'name': 'quilted',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 304,
#    'name': 'pleat',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 305,
#    'name': 'gathering',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 306,
#    'name': 'smocking',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 307,
#    'name': 'tiered',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 308,
#    'name': 'cutout',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 309,
#    'name': 'slit',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 310,
#    'name': 'perforated',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 311,
#    'name': 'lining',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 312,
#    'name': 'applique(a)',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 313,
#    'name': 'bead(a)',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 314,
#    'name': 'rivet(a)',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 315,
#    'name': 'sequin(a)',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 316,
#    'name': 'no special manufacturing technique',
#    'supercategory': 'textile finishing, manufacturing techniques',
#    'level': 1},
#   {'id': 317,
#    'name': 'plain (pattern)',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 318,
#    'name': 'abstract',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 319,
#    'name': 'cartoon',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 320,
#    'name': 'letters, numbers',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 321,
#    'name': 'camouflage',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 322, 'name': 'check', 'supercategory': 'textile pattern', 'level': 1},
#   {'id': 323, 'name': 'dot', 'supercategory': 'textile pattern', 'level': 1},
#   {'id': 324,
#    'name': 'fair isle',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 325,
#    'name': 'floral',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 326,
#    'name': 'geometric',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 327,
#    'name': 'paisley',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 328,
#    'name': 'stripe',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 329,
#    'name': 'houndstooth (pattern)',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 330,
#    'name': 'herringbone (pattern)',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 331,
#    'name': 'chevron',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 332,
#    'name': 'argyle',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 333, 'name': 'leopard', 'supercategory': 'animal', 'level': 2},
#   {'id': 334,
#    'name': 'snakeskin (pattern)',
#    'supercategory': 'animal',
#    'level': 2},
#   {'id': 335, 'name': 'cheetah', 'supercategory': 'animal', 'level': 2},
#   {'id': 336, 'name': 'peacock', 'supercategory': 'animal', 'level': 2},
#   {'id': 337, 'name': 'zebra', 'supercategory': 'animal', 'level': 2},
#   {'id': 338, 'name': 'giraffe', 'supercategory': 'animal', 'level': 2},
#   {'id': 339,
#    'name': 'toile de jouy',
#    'supercategory': 'textile pattern',
#    'level': 1},
#   {'id': 340,
#    'name': 'plant',
#    'supercategory': 'textile pattern',
#    'level': 1}]}

# %%
# _Start: Classes and Attributes processing 
df_categories = pd.DataFrame(label_desc['categories'])
df_attributes = pd.DataFrame(label_desc['attributes'])
# _End: Classes and Attributes processing 

n_classes = len(label_desc['categories'])
n_attributes = len(label_desc['attributes'])

print('Classes: {0} \nAttributes: {1}'.
     format(str(n_classes), str(n_attributes)))
# Out:
# Classes: 46
# Attributes: 294

# %%
df_categories
# Out:
#     id                                     name   supercategory  level
# 0    0                            shirt, blouse       upperbody      2
# 1    1                 top, t-shirt, sweatshirt       upperbody      2
# 2    2                                  sweater       upperbody      2
# 3    3                                 cardigan       upperbody      2
# 4    4                                   jacket       upperbody      2
# 5    5                                     vest       upperbody      2
# 6    6                                    pants       lowerbody      2
# 7    7                                   shorts       lowerbody      2
# 8    8                                    skirt       lowerbody      2
# 9    9                                     coat       wholebody      2
# 10  10                                    dress       wholebody      2
# 11  11                                 jumpsuit       wholebody      2
# 12  12                                     cape       wholebody      2
# 13  13                                  glasses            head      2
# 14  14                                      hat            head      2
# 15  15  headband, head covering, hair accessory            head      2
# 16  16                                      tie            neck      2
# 17  17                                    glove  arms and hands      2
# 18  18                                    watch  arms and hands      2
# 19  19                                     belt           waist      2
# 20  20                               leg warmer   legs and feet      2
# 21  21                        tights, stockings   legs and feet      2
# 22  22                                     sock   legs and feet      2
# 23  23                                     shoe   legs and feet      2
# 24  24                              bag, wallet          others      2
# 25  25                                    scarf          others      2
# 26  26                                 umbrella          others      2
# 27  27                                     hood   garment parts      2
# 28  28                                   collar   garment parts      2
# 29  29                                    lapel   garment parts      2
# 30  30                                epaulette   garment parts      2
# 31  31                                   sleeve   garment parts      2
# 32  32                                   pocket   garment parts      2
# 33  33                                 neckline   garment parts      2
# 34  34                                   buckle        closures      2
# 35  35                                   zipper        closures      2
# 36  36                                 applique     decorations      2
# 37  37                                     bead     decorations      2
# 38  38                                      bow     decorations      2
# 39  39                                   flower     decorations      2
# 40  40                                   fringe     decorations      2
# 41  41                                   ribbon     decorations      2
# 42  42                                    rivet     decorations      2
# 43  43                                   ruffle     decorations      2
# 44  44                                   sequin     decorations      2
# 45  45                                   tassel     decorations      2

# %%
df_attributes
# Out:
#       id               name    supercategory  level
# 0      0  classic (t-shirt)         nickname      1
# 1      1       polo (shirt)         nickname      1
# 2      2         undershirt         nickname      1
# 3      3     henley (shirt)         nickname      1
# 4      4   ringer (t-shirt)         nickname      1
# ..   ...                ...              ...    ...
# 289  336            peacock           animal      2
# 290  337              zebra           animal      2
# 291  338            giraffe           animal      2
# 292  339      toile de jouy  textile pattern      1
# 293  340              plant  textile pattern      1
#
# [294 rows x 4 columns]

# %%
df_categories.supercategory.unique()
# Out:
# array(['upperbody', 'lowerbody', 'wholebody', 'head', 'neck',
#        'arms and hands', 'waist', 'legs and feet', 'others',
#        'garment parts', 'closures', 'decorations'], dtype=object)

# %%
df_attributes.supercategory.unique()
# Out:
# array(['nickname', 'silhouette', 'waistline', 'length', 'neckline type',
#        'opening type', 'non-textile material type', 'leather',
#        'textile finishing, manufacturing techniques', 'textile pattern',
#        'animal'], dtype=object)

# %% [markdown]
# # Check out training images and their masks
# * [iMaterialist - Segmentation task](https://www.kaggle.com/yanastamenova/imaterialist-segmentation-task)

# %%
def show_images(size = 4, figsize = (12, 12)):
    #get the images
    image_ids = train_data['ImageId'].unique()[:size]
    images = []
    
    for image_id in image_ids:
        images.append(mpimg.imread('{0}/train/{1}.jpg'.format(data_dir, image_id)))
        
    count = 0
    
    fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = figsize)
    for row in ax:
        for col in row:
            col.imshow(images[count])
            col.axis('off')
            count += 1
    plt.show()
    gc.collect()

# %%
show_images()

# %%
#Function to create mask
def create_mask(size):
    image_ids = train_data['ImageId'].unique()[:size] #get a number of images
    images_meta = [] #to be added in this array
    
    for image_id in image_ids:
        img = mpimg.imread('{0}/train/{1}.jpg'.format(data_dir, image_id))
        images_meta.append({
            'image': img,
            'shape': img.shape,
            'encoded_pixels': train_data[train_data['ImageId'] == image_id]['EncodedPixels'],
            'class_ids': train_data[train_data['ImageId'] == image_id]['ClassId']
        })
        
    masks = []
    
    for image in images_meta:
        shape = image.get('shape') #get via key
        encoded_pixels = list(image.get('encoded_pixels')) 
        class_ids = list(image.get('class_ids'))
        
        #Initialize numpy array with shape same as image size
        height, width = shape[:2] 
        mask = np.zeros((height, width)).reshape(-1) 
        # (-1) 'The new shape should be compatible with the original shape'
        # numpy allow us to give one of new shape parameter as -1 but not (-1, -1)).
        # It means that it is an unknown dimension and we want numpy to figure it out.
        # And numpy will figure this by looking at the 'length of the array and remaining
        # dimensions' and making sure it satisfies the above mentioned criteria
        
        #Iterate over encoded pixels and create mask
        for segment, (pixel_str, class_id) in enumerate(zip(encoded_pixels, class_ids)):
            splitted_pixels = list(map(int, pixel_str.split()))      #split the pixels string
            pixel_starts = splitted_pixels[::2]                      #choose every second element
            run_lengths = splitted_pixels[1::2]                      #start from 1 with step size 2
            assert max(pixel_starts) < mask.shape[0]                 #make sure it is ok
            
            for pixel_start, run_length in zip(pixel_starts, run_lengths):
                pixel_start = int(pixel_start) - 1
                run_length = int(run_length)
                mask[pixel_start:pixel_start+run_length] = 255 - class_id 
        masks.append(mask.reshape((height, width), order = 'F'))
    
    return masks, images_meta

# %%
def plot_segmented_images(size = 4, figsize = (14, 14)):
    #First, create masks from given segments
    masks, images_meta = create_mask(size)
    
    #Plot images
    
    count = 0
    
    fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = figsize)
    for row in ax:
        for col in row:
            col.imshow(images_meta[count]['image'])
            col.imshow(masks[count], alpha = 0.50)
            col.axis('off')
            count += 1
    plt.show()
    gc.collect()

# %%
plot_segmented_images()

# %% [markdown]
# # Grouping data based on each identical image
# * refer to [here](https://www.kaggle.com/yanastamenova/imaterialist-segmentation-task)
# * Use the ```pandas``` for grouping proces
# * [Custom Dataset format for PyTorch](https://wikidocs.net/57165)
# * [Building Efficient Custom Datasets in PyTorch](https://towardsdatascience.com/building-efficient-custom-datasets-in-pytorch-2563b946fd9f)
# * [fashionChallenge-SemSegmentation/dataHandling.py](https://github.com/mcreduardo/fashionChallenge-SemSegmentation/blob/master/dataHandling.py)
# * [Torchvision Object Detection](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#torchvision-object-detection-finetuning-tutorial)
# * [Pytorch, Custom Dataset, YouTube](https://www.youtube.com/watch?v=38hn-FpRaJs)
# * [IMaterialist 2020: Starter EDA + Mask RCNN](https://www.kaggle.com/kaushal2896/imaterialist-2020-starter-eda-mask-rcnn)

# %%
images_data = train_data.groupby('ImageId')['EncodedPixels', 'ClassId'].agg(lambda x: list(x))
dimensions_data = train_data.groupby('ImageId')['Height', 'Width'].mean()

images_data = images_data.join(dimensions_data, on='ImageId')
# Out:
# C:\Users\camin\anaconda3\envs\pytorch_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\camin\anaconda3\envs\pytorch_env\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
images_data.head(5)
# Out:
#                                                                       EncodedPixels  \
# ImageId
# 00000663ed1ff0c4e0132b9b9ac53f6e  [6068157 7 6073371 20 6078584 34 6083797 48 60...
# 0000fe7c9191fba733c8a69cfaf962b7  [2201176 1 2203623 3 2206071 5 2208518 8 22109...
# 0002ec21ddb8477e98b2cbb87ea2e269  [2673735 2 2676734 8 2679734 13 2682733 19 268...
# 0002f5a0ebc162ecfb73e2c91e3b8f62  [435 132 1002 132 1569 132 2136 132 2703 132 3...
# 0004467156e47b0eb6de4aa6479cbd15  [132663 8 133396 25 134130 41 134868 53 135611...
#
#                                                             ClassId  Height  \
# ImageId
# 00000663ed1ff0c4e0132b9b9ac53f6e  [6, 0, 28, 31, 32, 32, 31, 29, 4]    5214
# 0000fe7c9191fba733c8a69cfaf962b7                            [33, 1]    2448
# 0002ec21ddb8477e98b2cbb87ea2e269                   [33, 10, 23, 23]    3000
# 0002f5a0ebc162ecfb73e2c91e3b8f62                       [10, 33, 15]     567
# 0004467156e47b0eb6de4aa6479cbd15               [10, 33, 31, 31, 15]     750
#
#                                   Width
# ImageId
# 00000663ed1ff0c4e0132b9b9ac53f6e   3676
# 0000fe7c9191fba733c8a69cfaf962b7   2448
# 0002ec21ddb8477e98b2cbb87ea2e269   1997
# 0002f5a0ebc162ecfb73e2c91e3b8f62    400
# 0004467156e47b0eb6de4aa6479cbd15    500

# %%
print("Total images: ", len(images_data))
# Out:
# Total images:  45623

# %%
class Fashion2020dataset(torch.utils.data.Dataset):
    def __init__(self, data_root, transforms, df_csv:str ):  # _to load and preprocess for the dataset. 
        
        super().__init__()
        self.data_root = data_root         
        self.transforms = transforms 
        self.imgs = list(sorted(os.listdir(os.path.join(data_root, "train"))))
        
        # _Start: read .csv with pandas for DataFormat description 
        self.df_csv = pd.read_csv(os.path.join(data_root, df_csv))  
        self.image_ids = self.df_csv["ImageId"].unique() # to get all image names
        
        
         
    def __getitem__(self, idx): # _to get a specific item.                        
        
        imgID = self.image_ids[idx]       
        #imgID = self.imgs[idx]       
        
        print(f"Image loading: {imgID}")
        
        pil_im = Image.open("{0}/train/{1}.jpg".format(self.data_root, str(imgID)))
        img = np.asarray(pil_im)
        
        images_meta = {} # 
        images_meta.update({ "image":img,
                             "shape":img.shape, 
                             "encoded_pixels": self.df_csv[self.df_csv['ImageId'] == imgID]['EncodedPixels'],
                             "class_ids" : self.df_csv[self.df_csv['ImageId'] == imgID]['ClassId']                                   
                             })
            
        # _Start: create masks with decoding and bbox from them 
        masks = []     
        boxes = [] 

        shape = images_meta.get("shape")  # _get via key of dict() 
        encoded_pixels = list(images_meta.get("encoded_pixels"))
        class_ids = list(images_meta.get("class_ids"))
        print(class_ids)
            
        # _Initialze an empty array with the same shape as the image 
        height, width = shape[:2] 
        mask = np.zeros((height, width)).reshape(-1)
        # (-1) 'The new shape should be compatible with the original shape'
            
        pbarLoad = tqdm(zip(encoded_pixels, class_ids))
        for segment, (pixel_str, class_id) in enumerate(pbarLoad):
            pbarLoad.set_description(f"Loading encoded pixels...: {segment}" )
            splitted_pixels = list(map(int, pixel_str.split())) #split the pixels string
            pixel_starts = splitted_pixels[::2] #choose every second element
            run_lengths = splitted_pixels[1::2]  #start from 1 with step size 2
               
            assert max(pixel_starts) < mask.shape[0]  
            
            pbarDecode = tqdm(zip(pixel_starts, run_lengths))    
            for pixel_start, run_length in pbarDecode:
                pbarDecode.set_description(f"Decoding masks...: {pixel_start}" )
                pixel_start = int(pixel_start) - 1
                run_length = int(run_length)
                mask[pixel_start:pixel_start+run_length] = 255 - class_id *4
                         
            
            mask = mask.reshape((height, width), order = 'F')
            masks.append(mask)
            
            # _Start: get bounding box coordinates from each mask 
            pos = np.where(mask)
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])
            # _End: get bounding box coordinates from each mask 
            
            mask = np.zeros((height, width)).reshape(-1) # re-initialize 
        # _End: create masks with decoding 
        
        
        
        # _Start: convert everything into a torch.Tensor 
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        class_ids = torch.as_tensor(class_ids, dtype=torch.uint8)
        masks = torch.as_tensor(masks, dtype=torch.uint8)  
        image_id = torch.tensor([idx])
        
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])      
        
        iscrowd = torch.zeros(len(class_ids,), dtype=torch.int64) # suppose all instances are not crowd
        # _End: convert everything into a torch.Tensor
        
        
        target = {}
        target["boxes"] = boxes
        target["class_ids"] = class_ids
        target["masks"] = masks
        target["image_id"] = image_id 
        target["area"] = area
        target["iscrowd"] = iscrowd           
        
        
        if self.transforms is not None: 
            img, target = self.transforms(img, target)           
        
        return img, target
    
    def __len__(self):          # _to return the length of data samples in the dataset. 
        return len(self.imgs)

# %%
a = Fashion2020dataset(data_root= data_dir, transforms=None, df_csv="train.csv")

# %%
img, target = a.__getitem__(100)
# Out:
# Loading encoded pixels...: 0: : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Decoding masks...: 196630: : 0it [00:00, ?it/s]
# Decoding masks...: 197651: : 0it [00:00, ?it/s]
# Decoding masks...: 198672: : 0it [00:00, ?it/s]
# Decoding masks...: 199693: : 0it [00:00, ?it/s]
# Decoding masks...: 200714: : 0it [00:00, ?it/s]
# Decoding masks...: 201737: : 0it [00:00, ?it/s]
# Decoding masks...: 202760: : 0it [00:00, ?it/s]
# Decoding masks...: 203783: : 0it [00:00, ?it/s]
# Decoding masks...: 204807: : 0it [00:00, ?it/s]
# Decoding masks...: 205830: : 0it [00:00, ?it/s]
# Decoding masks...: 206854: : 0it [00:00, ?it/s]
# Decoding masks...: 207877: : 0it [00:00, ?it/s]
# Decoding masks...: 208900: : 0it [00:00, ?it/s]
# Decoding masks...: 209924: : 0it [00:00, ?it/s]
# Decoding masks...: 210948: : 0it [00:00, ?it/s]
# Decoding masks...: 211971: : 0it [00:00, ?it/s]
# Decoding masks...: 212995: : 0it [00:00, ?it/s]
# Decoding masks...: 214019: : 0it [00:00, ?it/s]
# Decoding masks...: 215042: : 0it [00:00, ?it/s]
# Decoding masks...: 216066: : 0it [00:00, ?it/s]
# Decoding masks...: 217090: : 0it [00:00, ?it/s]
# Decoding masks...: 218114: : 0it [00:00, ?it/s]
# Decoding masks...: 219139: : 0it [00:00, ?it/s]
# Decoding masks...: 220163: : 0it [00:00, ?it/s]
# Decoding masks...: 221187: : 0it [00:00, ?it/s]
# Decoding masks...: 222211: : 0it [00:00, ?it/s]
# Decoding masks...: 223236: : 0it [00:00, ?it/s]
# Decoding masks...: 224260: : 0it [00:00, ?it/s]
# Decoding masks...: 225284: : 0it [00:00, ?it/s]
# Decoding masks...: 226309: : 0it [00:00, ?it/s]
# Decoding masks...: 227333: : 0it [00:00, ?it/s]
# Decoding masks...: 228357: : 0it [00:00, ?it/s]
# Decoding masks...: 229382: : 0it [00:00, ?it/s]
# Decoding masks...: 230407: : 0it [00:00, ?it/s]
# Decoding masks...: 231432: : 0it [00:00, ?it/s]
# Decoding masks...: 232457: : 0it [00:00, ?it/s]
# Decoding masks...: 233483: : 0it [00:00, ?it/s]
# Decoding masks...: 234509: : 0it [00:00, ?it/s]
# Decoding masks...: 235534: : 0it [00:00, ?it/s]
# Decoding masks...: 236560: : 0it [00:00, ?it/s]
# Decoding masks...: 237586: : 0it [00:00, ?it/s]
# Decoding masks...: 238611: : 0it [00:00, ?it/s]
# Decoding masks...: 239635: : 0it [00:00, ?it/s]
# Decoding masks...: 240659: : 0it [00:00, ?it/s]
# Decoding masks...: 241683: : 0it [00:00, ?it/s]
# Decoding masks...: 242708: : 0it [00:00, ?it/s]
# Decoding masks...: 243732: : 0it [00:00, ?it/s]
# Decoding masks...: 244756: : 0it [00:00, ?it/s]
# Decoding masks...: 245780: : 0it [00:00, ?it/s]
# Decoding masks...: 246793: : 0it [00:00, ?it/s]
# Decoding masks...: 247816: : 0it [00:00, ?it/s]
# Decoding masks...: 248840: : 0it [00:00, ?it/s]
# Decoding masks...: 249864: : 0it [00:00, ?it/s]
# Decoding masks...: 250887: : 0it [00:00, ?it/s]
# Decoding masks...: 251911: : 0it [00:00, ?it/s]
# Decoding masks...: 252934: : 0it [00:00, ?it/s]
# Decoding masks...: 253958: : 0it [00:00, ?it/s]
# Decoding masks...: 253958: : 57it [00:00, 554.87it/s]
# Decoding masks...: 254982: : 57it [00:00, 554.87it/s]
# Decoding masks...: 256005: : 57it [00:00, 554.87it/s]
# Decoding masks...: 257029: : 57it [00:00, 554.87it/s]
# Decoding masks...: 258053: : 57it [00:00, 554.87it/s]
# Decoding masks...: 259076: : 57it [00:00, 554.87it/s]
# Decoding masks...: 260100: : 57it [00:00, 554.87it/s]
# Decoding masks...: 261124: : 57it [00:00, 554.87it/s]
# Decoding masks...: 262147: : 57it [00:00, 554.87it/s]
# Decoding masks...: 263171: : 57it [00:00, 554.87it/s]
# Decoding masks...: 264195: : 57it [00:00, 554.87it/s]
# Decoding masks...: 265219: : 57it [00:00, 554.87it/s]
# Decoding masks...: 266243: : 57it [00:00, 554.87it/s]
# Decoding masks...: 267266: : 57it [00:00, 554.87it/s]
# Decoding masks...: 268290: : 57it [00:00, 554.87it/s]
# Decoding masks...: 269314: : 57it [00:00, 554.87it/s]
# Decoding masks...: 270338: : 57it [00:00, 554.87it/s]
# Decoding masks...: 271362: : 57it [00:00, 554.87it/s]
# Decoding masks...: 272385: : 57it [00:00, 554.87it/s]
# Image loading: 008324a52c5910d338807fb785ebaa0a
# [13, 10, 31, 31, 28, 23]
# Decoding masks...: 273409: : 57it [00:00, 554.87it/s]
# Decoding masks...: 274433: : 57it [00:00, 554.87it/s]
# Decoding masks...: 275457: : 57it [00:00, 554.87it/s]
# Decoding masks...: 276482: : 57it [00:00, 554.87it/s]
# Decoding masks...: 277506: : 57it [00:00, 554.87it/s]
# Decoding masks...: 278530: : 57it [00:00, 554.87it/s]
# Decoding masks...: 279555: : 57it [00:00, 554.87it/s]
# Decoding masks...: 280579: : 57it [00:00, 554.87it/s]
# Decoding masks...: 281603: : 57it [00:00, 554.87it/s]
# Decoding masks...: 282628: : 57it [00:00, 554.87it/s]
# Decoding masks...: 283652: : 57it [00:00, 554.87it/s]
# Decoding masks...: 284676: : 57it [00:00, 554.87it/s]
# Decoding masks...: 285701: : 57it [00:00, 554.87it/s]
# Decoding masks...: 286725: : 57it [00:00, 554.87it/s]
# Decoding masks...: 287749: : 57it [00:00, 554.87it/s]
# Decoding masks...: 288774: : 57it [00:00, 554.87it/s]
# Decoding masks...: 289798: : 57it [00:00, 554.87it/s]
# Decoding masks...: 290823: : 57it [00:00, 554.87it/s]
# Decoding masks...: 291849: : 57it [00:00, 554.87it/s]
# Decoding masks...: 292874: : 57it [00:00, 554.87it/s]
# Decoding masks...: 293900: : 57it [00:00, 554.87it/s]
# Decoding masks...: 294926: : 57it [00:00, 554.87it/s]
# Decoding masks...: 295954: : 57it [00:00, 554.87it/s]
# Decoding masks...: 296984: : 57it [00:00, 554.87it/s]
# Decoding masks...: 298015: : 57it [00:00, 554.87it/s]
# Decoding masks...: 299042: : 57it [00:00, 554.87it/s]
# Decoding masks...: 300067: : 57it [00:00, 554.87it/s]
# Decoding masks...: 301092: : 57it [00:00, 554.87it/s]
# Decoding masks...: 302117: : 57it [00:00, 554.87it/s]
# Decoding masks...: 303142: : 57it [00:00, 554.87it/s]
# Decoding masks...: 304167: : 57it [00:00, 554.87it/s]
# Decoding masks...: 305192: : 57it [00:00, 554.87it/s]
# Decoding masks...: 306217: : 57it [00:00, 554.87it/s]
# Decoding masks...: 307241: : 109it [00:00, 603.93it/s][A
# Loading encoded pixels...: 1: : 1it [00:00,  5.09it/s]
# 0it [00:00, ?it/s]
# Decoding masks...: 288: : 0it [00:00, ?it/s]
# Decoding masks...: 1308: : 0it [00:00, ?it/s]
# Decoding masks...: 2327: : 0it [00:00, ?it/s]
# Decoding masks...: 3347: : 0it [00:00, ?it/s]
# Decoding masks...: 4367: : 0it [00:00, ?it/s]
# Decoding masks...: 5388: : 0it [00:00, ?it/s]
# Decoding masks...: 6411: : 0it [00:00, ?it/s]
# Decoding masks...: 7434: : 0it [00:00, ?it/s]
# Decoding masks...: 8457: : 0it [00:00, ?it/s]
# Decoding masks...: 9480: : 0it [00:00, ?it/s]
# Decoding masks...: 10503: : 0it [00:00, ?it/s]
# Decoding masks...: 11526: : 0it [00:00, ?it/s]
# Decoding masks...: 12549: : 0it [00:00, ?it/s]
# Decoding masks...: 13572: : 0it [00:00, ?it/s]
# Decoding masks...: 14595: : 0it [00:00, ?it/s]
# Decoding masks...: 15618: : 0it [00:00, ?it/s]
# Decoding masks...: 16641: : 0it [00:00, ?it/s]
# Decoding masks...: 17663: : 0it [00:00, ?it/s]
# Decoding masks...: 18687: : 0it [00:00, ?it/s]
# Decoding masks...: 19711: : 0it [00:00, ?it/s]
# Decoding masks...: 20735: : 0it [00:00, ?it/s]
# Decoding masks...: 21759: : 0it [00:00, ?it/s]
# Decoding masks...: 22783: : 0it [00:00, ?it/s]
# Decoding masks...: 23807: : 0it [00:00, ?it/s]
# Decoding masks...: 24832: : 0it [00:00, ?it/s]
# Decoding masks...: 25856: : 0it [00:00, ?it/s]
# Decoding masks...: 26880: : 0it [00:00, ?it/s]
# Decoding masks...: 27904: : 0it [00:00, ?it/s]
# Decoding masks...: 28928: : 0it [00:00, ?it/s]
# Decoding masks...: 29952: : 0it [00:00, ?it/s]
# Decoding masks...: 30976: : 0it [00:00, ?it/s]
# Decoding masks...: 32000: : 0it [00:00, ?it/s]
# Decoding masks...: 33024: : 0it [00:00, ?it/s]
# Decoding masks...: 34048: : 0it [00:00, ?it/s]
# Decoding masks...: 35072: : 0it [00:00, ?it/s]
# Decoding masks...: 36096: : 0it [00:00, ?it/s]
# Decoding masks...: 37120: : 0it [00:00, ?it/s]
# Decoding masks...: 38145: : 0it [00:00, ?it/s]
# Decoding masks...: 39169: : 0it [00:00, ?it/s]
# Decoding masks...: 40193: : 0it [00:00, ?it/s]
# Decoding masks...: 41217: : 0it [00:00, ?it/s]
# Decoding masks...: 42241: : 0it [00:00, ?it/s]
# Decoding masks...: 43265: : 0it [00:00, ?it/s]
# Decoding masks...: 44285: : 0it [00:00, ?it/s]
# Decoding masks...: 45306: : 0it [00:00, ?it/s]
# Decoding masks...: 46330: : 0it [00:00, ?it/s]
# Decoding masks...: 47353: : 0it [00:00, ?it/s]
# Decoding masks...: 48377: : 0it [00:00, ?it/s]
# Decoding masks...: 49401: : 0it [00:00, ?it/s]
# Decoding masks...: 50425: : 0it [00:00, ?it/s]
# Decoding masks...: 51449: : 0it [00:00, ?it/s]
# Decoding masks...: 52472: : 0it [00:00, ?it/s]
# Decoding masks...: 53496: : 0it [00:00, ?it/s]
# Decoding masks...: 54520: : 0it [00:00, ?it/s]
# Decoding masks...: 55544: : 0it [00:00, ?it/s]
# Decoding masks...: 56568: : 0it [00:00, ?it/s]
# Decoding masks...: 57591: : 0it [00:00, ?it/s]
# Decoding masks...: 58615: : 0it [00:00, ?it/s]
# Decoding masks...: 59639: : 0it [00:00, ?it/s]
# Decoding masks...: 60662: : 0it [00:00, ?it/s]
# Decoding masks...: 61685: : 0it [00:00, ?it/s]
# Decoding masks...: 62708: : 0it [00:00, ?it/s]
# Decoding masks...: 63732: : 0it [00:00, ?it/s]
# Decoding masks...: 64755: : 0it [00:00, ?it/s]
# Decoding masks...: 65778: : 0it [00:00, ?it/s]
# Decoding masks...: 66801: : 0it [00:00, ?it/s]
# Decoding masks...: 66801: : 66it [00:00, 655.22it/s]
# Decoding masks...: 67825: : 66it [00:00, 655.22it/s]
# Decoding masks...: 68848: : 66it [00:00, 655.22it/s]
# Decoding masks...: 69871: : 66it [00:00, 655.22it/s]
# Decoding masks...: 70894: : 66it [00:00, 655.22it/s]
# Decoding masks...: 71918: : 66it [00:00, 655.22it/s]
# Decoding masks...: 72941: : 66it [00:00, 655.22it/s]
# Decoding masks...: 73964: : 66it [00:00, 655.22it/s]
# Decoding masks...: 74987: : 66it [00:00, 655.22it/s]
# Decoding masks...: 76011: : 66it [00:00, 655.22it/s]
# Decoding masks...: 77034: : 66it [00:00, 655.22it/s]
# Decoding masks...: 78057: : 66it [00:00, 655.22it/s]
# Decoding masks...: 78123: : 66it [00:00, 655.22it/s]
# Decoding masks...: 79080: : 66it [00:00, 655.22it/s]
# Decoding masks...: 79150: : 66it [00:00, 655.22it/s]
# Decoding masks...: 80104: : 66it [00:00, 655.22it/s]
# Decoding masks...: 80177: : 66it [00:00, 655.22it/s]
# Decoding masks...: 81127: : 66it [00:00, 655.22it/s]
# Decoding masks...: 81204: : 66it [00:00, 655.22it/s]
# Decoding masks...: 82150: : 66it [00:00, 655.22it/s]
# Decoding masks...: 82231: : 66it [00:00, 655.22it/s]
# Decoding masks...: 83173: : 66it [00:00, 655.22it/s]
# Decoding masks...: 84197: : 66it [00:00, 655.22it/s]
# Decoding masks...: 85220: : 66it [00:00, 655.22it/s]
# Decoding masks...: 86243: : 66it [00:00, 655.22it/s]
# Decoding masks...: 87266: : 66it [00:00, 655.22it/s]
# Decoding masks...: 88290: : 66it [00:00, 655.22it/s]
# Decoding masks...: 89313: : 66it [00:00, 655.22it/s]
# Decoding masks...: 90336: : 66it [00:00, 655.22it/s]
# Decoding masks...: 91359: : 66it [00:00, 655.22it/s]
# Decoding masks...: 92382: : 66it [00:00, 655.22it/s]
# Decoding masks...: 93406: : 66it [00:00, 655.22it/s]
# Decoding masks...: 94429: : 66it [00:00, 655.22it/s]
# Decoding masks...: 95452: : 66it [00:00, 655.22it/s]
# Decoding masks...: 96475: : 66it [00:00, 655.22it/s]
# Decoding masks...: 97498: : 66it [00:00, 655.22it/s]
# Decoding masks...: 98522: : 66it [00:00, 655.22it/s]
# Decoding masks...: 99545: : 66it [00:00, 655.22it/s]
# Decoding masks...: 100568: : 66it [00:00, 655.22it/s]
# Decoding masks...: 101591: : 66it [00:00, 655.22it/s]
# Decoding masks...: 102614: : 66it [00:00, 655.22it/s]
# Decoding masks...: 103638: : 66it [00:00, 655.22it/s]
# Decoding masks...: 104661: : 66it [00:00, 655.22it/s]
# Decoding masks...: 105684: : 66it [00:00, 655.22it/s]
# Decoding masks...: 106707: : 66it [00:00, 655.22it/s]
# Decoding masks...: 107730: : 66it [00:00, 655.22it/s]
# Decoding masks...: 108754: : 66it [00:00, 655.22it/s]
# Decoding masks...: 109777: : 66it [00:00, 655.22it/s]
# Decoding masks...: 110800: : 66it [00:00, 655.22it/s]
# Decoding masks...: 111823: : 66it [00:00, 655.22it/s]
# Decoding masks...: 112846: : 66it [00:00, 655.22it/s]
# Decoding masks...: 113870: : 66it [00:00, 655.22it/s]
# Decoding masks...: 114893: : 66it [00:00, 655.22it/s]
# Decoding masks...: 115916: : 66it [00:00, 655.22it/s]
# Decoding masks...: 116939: : 66it [00:00, 655.22it/s]
# Decoding masks...: 117962: : 66it [00:00, 655.22it/s]
# Decoding masks...: 118986: : 66it [00:00, 655.22it/s]
# Decoding masks...: 120009: : 66it [00:00, 655.22it/s]
# Decoding masks...: 121032: : 66it [00:00, 655.22it/s]
# Decoding masks...: 122055: : 66it [00:00, 655.22it/s]
# Decoding masks...: 123078: : 66it [00:00, 655.22it/s]
# Decoding masks...: 124101: : 66it [00:00, 655.22it/s]
# Decoding masks...: 125124: : 66it [00:00, 655.22it/s]
# Decoding masks...: 126147: : 66it [00:00, 655.22it/s]
# Decoding masks...: 127170: : 66it [00:00, 655.22it/s]
# Decoding masks...: 128192: : 66it [00:00, 655.22it/s]
# Decoding masks...: 129215: : 66it [00:00, 655.22it/s]
# Decoding masks...: 130238: : 66it [00:00, 655.22it/s]
# Decoding masks...: 131261: : 66it [00:00, 655.22it/s]
# Decoding masks...: 131261: : 134it [00:00, 659.13it/s]
# Decoding masks...: 132284: : 134it [00:00, 659.13it/s]
# Decoding masks...: 133306: : 134it [00:00, 659.13it/s]
# Decoding masks...: 134329: : 134it [00:00, 659.13it/s]
# Decoding masks...: 135352: : 134it [00:00, 659.13it/s]
# Decoding masks...: 136375: : 134it [00:00, 659.13it/s]
# Decoding masks...: 137398: : 134it [00:00, 659.13it/s]
# Decoding masks...: 138420: : 134it [00:00, 659.13it/s]
# Decoding masks...: 139443: : 134it [00:00, 659.13it/s]
# Decoding masks...: 140466: : 134it [00:00, 659.13it/s]
# Decoding masks...: 141489: : 134it [00:00, 659.13it/s]
# Decoding masks...: 142512: : 134it [00:00, 659.13it/s]
# Decoding masks...: 143534: : 134it [00:00, 659.13it/s]
# Decoding masks...: 144557: : 134it [00:00, 659.13it/s]
# Decoding masks...: 145580: : 134it [00:00, 659.13it/s]
# Decoding masks...: 146603: : 134it [00:00, 659.13it/s]
# Decoding masks...: 146924: : 134it [00:00, 659.13it/s]
# Decoding masks...: 147626: : 134it [00:00, 659.13it/s]
# Decoding masks...: 147941: : 134it [00:00, 659.13it/s]
# Decoding masks...: 148648: : 134it [00:00, 659.13it/s]
# Decoding masks...: 148958: : 134it [00:00, 659.13it/s]
# Decoding masks...: 149672: : 134it [00:00, 659.13it/s]
# Decoding masks...: 149976: : 134it [00:00, 659.13it/s]
# Decoding masks...: 150696: : 134it [00:00, 659.13it/s]
# Decoding masks...: 150995: : 134it [00:00, 659.13it/s]
# Decoding masks...: 151720: : 134it [00:00, 659.13it/s]
# Decoding masks...: 152014: : 134it [00:00, 659.13it/s]
# Decoding masks...: 152743: : 134it [00:00, 659.13it/s]
# Decoding masks...: 153033: : 134it [00:00, 659.13it/s]
# Decoding masks...: 153767: : 134it [00:00, 659.13it/s]
# Decoding masks...: 154051: : 134it [00:00, 659.13it/s]
# Decoding masks...: 154791: : 134it [00:00, 659.13it/s]
# Decoding masks...: 155070: : 134it [00:00, 659.13it/s]
# Decoding masks...: 155815: : 134it [00:00, 659.13it/s]
# Decoding masks...: 156089: : 134it [00:00, 659.13it/s]
# Decoding masks...: 156839: : 134it [00:00, 659.13it/s]
# Decoding masks...: 157108: : 134it [00:00, 659.13it/s]
# Decoding masks...: 157863: : 134it [00:00, 659.13it/s]
# Decoding masks...: 158129: : 134it [00:00, 659.13it/s]
# Decoding masks...: 158887: : 134it [00:00, 659.13it/s]
# Decoding masks...: 159152: : 134it [00:00, 659.13it/s]
# Decoding masks...: 159910: : 134it [00:00, 659.13it/s]
# Decoding masks...: 160175: : 134it [00:00, 659.13it/s]
# Decoding masks...: 160934: : 134it [00:00, 659.13it/s]
# Decoding masks...: 161198: : 134it [00:00, 659.13it/s]
# Decoding masks...: 161958: : 134it [00:00, 659.13it/s]
# Decoding masks...: 162221: : 134it [00:00, 659.13it/s]
# Decoding masks...: 162982: : 134it [00:00, 659.13it/s]
# Decoding masks...: 163244: : 134it [00:00, 659.13it/s]
# Decoding masks...: 164006: : 134it [00:00, 659.13it/s]
# Decoding masks...: 164268: : 134it [00:00, 659.13it/s]
# Decoding masks...: 165030: : 134it [00:00, 659.13it/s]
# Decoding masks...: 165291: : 134it [00:00, 659.13it/s]
# Decoding masks...: 166054: : 134it [00:00, 659.13it/s]
# Decoding masks...: 166314: : 134it [00:00, 659.13it/s]
# Decoding masks...: 167078: : 134it [00:00, 659.13it/s]
# Decoding masks...: 167337: : 134it [00:00, 659.13it/s]
# Decoding masks...: 168102: : 134it [00:00, 659.13it/s]
# Decoding masks...: 168360: : 134it [00:00, 659.13it/s]
# Decoding masks...: 169126: : 134it [00:00, 659.13it/s]
# Decoding masks...: 169383: : 134it [00:00, 659.13it/s]
# Decoding masks...: 170150: : 134it [00:00, 659.13it/s]
# Decoding masks...: 170406: : 134it [00:00, 659.13it/s]
# Decoding masks...: 171173: : 134it [00:00, 659.13it/s]
# Decoding masks...: 171429: : 134it [00:00, 659.13it/s]
# Decoding masks...: 172197: : 134it [00:00, 659.13it/s]
# Decoding masks...: 172453: : 134it [00:00, 659.13it/s]
# Decoding masks...: 173221: : 134it [00:00, 659.13it/s]
# Decoding masks...: 173221: : 201it [00:00, 660.83it/s]
# Decoding masks...: 173476: : 201it [00:00, 660.83it/s]
# Decoding masks...: 174245: : 201it [00:00, 660.83it/s]
# Decoding masks...: 174500: : 201it [00:00, 660.83it/s]
# Decoding masks...: 175269: : 201it [00:00, 660.83it/s]
# Decoding masks...: 175524: : 201it [00:00, 660.83it/s]
# Decoding masks...: 176293: : 201it [00:00, 660.83it/s]
# Decoding masks...: 176547: : 201it [00:00, 660.83it/s]
# Decoding masks...: 177317: : 201it [00:00, 660.83it/s]
# Decoding masks...: 177571: : 201it [00:00, 660.83it/s]
# Decoding masks...: 178341: : 201it [00:00, 660.83it/s]
# Decoding masks...: 178594: : 201it [00:00, 660.83it/s]
# Decoding masks...: 179365: : 201it [00:00, 660.83it/s]
# Decoding masks...: 179618: : 201it [00:00, 660.83it/s]
# Decoding masks...: 180389: : 201it [00:00, 660.83it/s]
# Decoding masks...: 180641: : 201it [00:00, 660.83it/s]
# Decoding masks...: 181414: : 201it [00:00, 660.83it/s]
# Decoding masks...: 181665: : 201it [00:00, 660.83it/s]
# Decoding masks...: 182439: : 201it [00:00, 660.83it/s]
# Decoding masks...: 182689: : 201it [00:00, 660.83it/s]
# Decoding masks...: 183463: : 201it [00:00, 660.83it/s]
# Decoding masks...: 183712: : 201it [00:00, 660.83it/s]
# Decoding masks...: 184488: : 201it [00:00, 660.83it/s]
# Decoding masks...: 184736: : 201it [00:00, 660.83it/s]
# Decoding masks...: 185513: : 201it [00:00, 660.83it/s]
# Decoding masks...: 185760: : 201it [00:00, 660.83it/s]
# Decoding masks...: 186537: : 201it [00:00, 660.83it/s]
# Decoding masks...: 186784: : 201it [00:00, 660.83it/s]
# Decoding masks...: 187562: : 201it [00:00, 660.83it/s]
# Decoding masks...: 187807: : 201it [00:00, 660.83it/s]
# Decoding masks...: 188587: : 201it [00:00, 660.83it/s]
# Decoding masks...: 188819: : 201it [00:00, 660.83it/s]
# Decoding masks...: 188831: : 201it [00:00, 660.83it/s]
# Decoding masks...: 189611: : 201it [00:00, 660.83it/s]
# Decoding masks...: 189843: : 201it [00:00, 660.83it/s]
# Decoding masks...: 189855: : 201it [00:00, 660.83it/s]
# Decoding masks...: 190636: : 201it [00:00, 660.83it/s]
# Decoding masks...: 190866: : 201it [00:00, 660.83it/s]
# Decoding masks...: 190879: : 201it [00:00, 660.83it/s]
# Decoding masks...: 191661: : 201it [00:00, 660.83it/s]
# Decoding masks...: 191890: : 201it [00:00, 660.83it/s]
# Decoding masks...: 191903: : 201it [00:00, 660.83it/s]
# Decoding masks...: 192685: : 201it [00:00, 660.83it/s]
# Decoding masks...: 192914: : 201it [00:00, 660.83it/s]
# Decoding masks...: 192927: : 201it [00:00, 660.83it/s]
# Decoding masks...: 193710: : 201it [00:00, 660.83it/s]
# Decoding masks...: 193938: : 201it [00:00, 660.83it/s]
# Decoding masks...: 193950: : 201it [00:00, 660.83it/s]
# Decoding masks...: 194735: : 201it [00:00, 660.83it/s]
# Decoding masks...: 194962: : 201it [00:00, 660.83it/s]
# Decoding masks...: 194974: : 201it [00:00, 660.83it/s]
# Decoding masks...: 195759: : 201it [00:00, 660.83it/s]
# Decoding masks...: 195986: : 201it [00:00, 660.83it/s]
# Decoding masks...: 195998: : 201it [00:00, 660.83it/s]
# Decoding masks...: 196784: : 201it [00:00, 660.83it/s]
# Decoding masks...: 197010: : 201it [00:00, 660.83it/s]
# Decoding masks...: 197022: : 201it [00:00, 660.83it/s]
# Decoding masks...: 197809: : 201it [00:00, 660.83it/s]
# Decoding masks...: 198034: : 201it [00:00, 660.83it/s]
# Decoding masks...: 198046: : 201it [00:00, 660.83it/s]
# Decoding masks...: 198833: : 201it [00:00, 660.83it/s]
# Decoding masks...: 199058: : 201it [00:00, 660.83it/s]
# Decoding masks...: 199070: : 201it [00:00, 660.83it/s]
# Decoding masks...: 199858: : 201it [00:00, 660.83it/s]
# Decoding masks...: 200082: : 201it [00:00, 660.83it/s]
# Decoding masks...: 200094: : 201it [00:00, 660.83it/s]
# Decoding masks...: 200870: : 201it [00:00, 660.83it/s]
# Decoding masks...: 200870: : 267it [00:00, 659.13it/s]
# Decoding masks...: 200883: : 267it [00:00, 659.13it/s]
# Decoding masks...: 201105: : 267it [00:00, 659.13it/s]
# Decoding masks...: 201118: : 267it [00:00, 659.13it/s]
# Decoding masks...: 201891: : 267it [00:00, 659.13it/s]
# Decoding masks...: 201907: : 267it [00:00, 659.13it/s]
# Decoding masks...: 202129: : 267it [00:00, 659.13it/s]
# Decoding masks...: 202142: : 267it [00:00, 659.13it/s]
# Decoding masks...: 202913: : 267it [00:00, 659.13it/s]
# Decoding masks...: 202932: : 267it [00:00, 659.13it/s]
# Decoding masks...: 203153: : 267it [00:00, 659.13it/s]
# Decoding masks...: 203166: : 267it [00:00, 659.13it/s]
# Decoding masks...: 203935: : 267it [00:00, 659.13it/s]
# Decoding masks...: 203957: : 267it [00:00, 659.13it/s]
# Decoding masks...: 204177: : 267it [00:00, 659.13it/s]
# Decoding masks...: 204190: : 267it [00:00, 659.13it/s]
# Decoding masks...: 204957: : 267it [00:00, 659.13it/s]
# Decoding masks...: 204981: : 267it [00:00, 659.13it/s]
# Decoding masks...: 205201: : 267it [00:00, 659.13it/s]
# Decoding masks...: 205214: : 267it [00:00, 659.13it/s]
# Decoding masks...: 205978: : 267it [00:00, 659.13it/s]
# Decoding masks...: 206006: : 267it [00:00, 659.13it/s]
# Decoding masks...: 206225: : 267it [00:00, 659.13it/s]
# Decoding masks...: 206238: : 267it [00:00, 659.13it/s]
# Decoding masks...: 207000: : 267it [00:00, 659.13it/s]
# Decoding masks...: 207031: : 267it [00:00, 659.13it/s]
# Decoding masks...: 207249: : 267it [00:00, 659.13it/s]
# Decoding masks...: 207262: : 267it [00:00, 659.13it/s]
# Decoding masks...: 208022: : 267it [00:00, 659.13it/s]
# Decoding masks...: 208055: : 267it [00:00, 659.13it/s]
# Decoding masks...: 208273: : 267it [00:00, 659.13it/s]
# Decoding masks...: 208286: : 267it [00:00, 659.13it/s]
# Decoding masks...: 209044: : 267it [00:00, 659.13it/s]
# Decoding masks...: 209080: : 267it [00:00, 659.13it/s]
# Decoding masks...: 209297: : 267it [00:00, 659.13it/s]
# Decoding masks...: 209311: : 267it [00:00, 659.13it/s]
# Decoding masks...: 210065: : 267it [00:00, 659.13it/s]
# Decoding masks...: 210105: : 267it [00:00, 659.13it/s]
# Decoding masks...: 210321: : 267it [00:00, 659.13it/s]
# Decoding masks...: 210335: : 267it [00:00, 659.13it/s]
# Decoding masks...: 211087: : 267it [00:00, 659.13it/s]
# Decoding masks...: 211345: : 267it [00:00, 659.13it/s]
# Decoding masks...: 211359: : 267it [00:00, 659.13it/s]
# Decoding masks...: 212110: : 267it [00:00, 659.13it/s]
# Decoding masks...: 212369: : 267it [00:00, 659.13it/s]
# Decoding masks...: 212383: : 267it [00:00, 659.13it/s]
# Decoding masks...: 213133: : 267it [00:00, 659.13it/s]
# Decoding masks...: 213393: : 267it [00:00, 659.13it/s]
# Decoding masks...: 213407: : 267it [00:00, 659.13it/s]
# Decoding masks...: 214157: : 267it [00:00, 659.13it/s]
# Decoding masks...: 214417: : 267it [00:00, 659.13it/s]
# Decoding masks...: 214431: : 267it [00:00, 659.13it/s]
# Decoding masks...: 215180: : 267it [00:00, 659.13it/s]
# Decoding masks...: 215441: : 267it [00:00, 659.13it/s]
# Decoding masks...: 215455: : 267it [00:00, 659.13it/s]
# Decoding masks...: 216203: : 267it [00:00, 659.13it/s]
# Decoding masks...: 216465: : 267it [00:00, 659.13it/s]
# Decoding masks...: 216479: : 267it [00:00, 659.13it/s]
# Decoding masks...: 217227: : 267it [00:00, 659.13it/s]
# Decoding masks...: 217489: : 267it [00:00, 659.13it/s]
# Decoding masks...: 217503: : 267it [00:00, 659.13it/s]
# Decoding masks...: 218250: : 267it [00:00, 659.13it/s]
# Decoding masks...: 218513: : 267it [00:00, 659.13it/s]
# Decoding masks...: 218527: : 267it [00:00, 659.13it/s]
# Decoding masks...: 219274: : 267it [00:00, 659.13it/s]
# Decoding masks...: 219537: : 267it [00:00, 659.13it/s]
# Decoding masks...: 219551: : 267it [00:00, 659.13it/s]
# Decoding masks...: 220297: : 267it [00:00, 659.13it/s]
# Decoding masks...: 220561: : 267it [00:00, 659.13it/s]
# Decoding masks...: 220574: : 267it [00:00, 659.13it/s]
# Decoding masks...: 221321: : 267it [00:00, 659.13it/s]
# Decoding masks...: 221585: : 267it [00:00, 659.13it/s]
# Decoding masks...: 221585: : 338it [00:00, 673.59it/s]
# Decoding masks...: 221597: : 338it [00:00, 673.59it/s]
# Decoding masks...: 222344: : 338it [00:00, 673.59it/s]
# Decoding masks...: 222609: : 338it [00:00, 673.59it/s]
# Decoding masks...: 222619: : 338it [00:00, 673.59it/s]
# Decoding masks...: 223368: : 338it [00:00, 673.59it/s]
# Decoding masks...: 223633: : 338it [00:00, 673.59it/s]
# Decoding masks...: 223642: : 338it [00:00, 673.59it/s]
# Decoding masks...: 224391: : 338it [00:00, 673.59it/s]
# Decoding masks...: 224657: : 338it [00:00, 673.59it/s]
# Decoding masks...: 224665: : 338it [00:00, 673.59it/s]
# Decoding masks...: 225414: : 338it [00:00, 673.59it/s]
# Decoding masks...: 225681: : 338it [00:00, 673.59it/s]
# Decoding masks...: 226438: : 338it [00:00, 673.59it/s]
# Decoding masks...: 226705: : 338it [00:00, 673.59it/s]
# Decoding masks...: 227461: : 338it [00:00, 673.59it/s]
# Decoding masks...: 227729: : 338it [00:00, 673.59it/s]
# Decoding masks...: 228485: : 338it [00:00, 673.59it/s]
# Decoding masks...: 228752: : 338it [00:00, 673.59it/s]
# Decoding masks...: 229508: : 338it [00:00, 673.59it/s]
# Decoding masks...: 229775: : 338it [00:00, 673.59it/s]
# Decoding masks...: 230533: : 338it [00:00, 673.59it/s]
# Decoding masks...: 230797: : 338it [00:00, 673.59it/s]
# Decoding masks...: 231559: : 338it [00:00, 673.59it/s]
# Decoding masks...: 231820: : 338it [00:00, 673.59it/s]
# Decoding masks...: 232585: : 338it [00:00, 673.59it/s]
# Decoding masks...: 232842: : 338it [00:00, 673.59it/s]
# Decoding masks...: 233611: : 338it [00:00, 673.59it/s]
# Decoding masks...: 233865: : 338it [00:00, 673.59it/s]
# Decoding masks...: 234637: : 338it [00:00, 673.59it/s]
# Decoding masks...: 234886: : 338it [00:00, 673.59it/s]
# Decoding masks...: 235663: : 338it [00:00, 673.59it/s]
# Decoding masks...: 235906: : 338it [00:00, 673.59it/s]
# Decoding masks...: 236689: : 338it [00:00, 673.59it/s]
# Decoding masks...: 236927: : 338it [00:00, 673.59it/s]
# Decoding masks...: 237715: : 338it [00:00, 673.59it/s]
# Decoding masks...: 238741: : 338it [00:00, 673.59it/s]
# Decoding masks...: 239767: : 338it [00:00, 673.59it/s]
# Decoding masks...: 240793: : 338it [00:00, 673.59it/s]
# Decoding masks...: 241819: : 338it [00:00, 673.59it/s]
# Decoding masks...: 242844: : 338it [00:00, 673.59it/s]
# Decoding masks...: 243870: : 338it [00:00, 673.59it/s]
# Decoding masks...: 244895: : 338it [00:00, 673.59it/s]
# Decoding masks...: 245921: : 338it [00:00, 673.59it/s]
# Decoding masks...: 246946: : 338it [00:00, 673.59it/s]
# Decoding masks...: 247971: : 338it [00:00, 673.59it/s]
# Decoding masks...: 248997: : 338it [00:00, 673.59it/s]
# Decoding masks...: 250022: : 338it [00:00, 673.59it/s]
# Decoding masks...: 251047: : 338it [00:00, 673.59it/s]
# Decoding masks...: 252072: : 338it [00:00, 673.59it/s]
# Decoding masks...: 253097: : 338it [00:00, 673.59it/s]
# Decoding masks...: 254122: : 338it [00:00, 673.59it/s]
# Decoding masks...: 255148: : 338it [00:00, 673.59it/s]
# Decoding masks...: 256173: : 338it [00:00, 673.59it/s]
# Decoding masks...: 257198: : 338it [00:00, 673.59it/s]
# Decoding masks...: 258223: : 338it [00:00, 673.59it/s]
# Decoding masks...: 259248: : 338it [00:00, 673.59it/s]
# Decoding masks...: 260273: : 338it [00:00, 673.59it/s]
# Decoding masks...: 261298: : 338it [00:00, 673.59it/s]
# Decoding masks...: 262323: : 338it [00:00, 673.59it/s]
# Decoding masks...: 263348: : 338it [00:00, 673.59it/s]
# Decoding masks...: 264373: : 338it [00:00, 673.59it/s]
# Decoding masks...: 265398: : 338it [00:00, 673.59it/s]
# Decoding masks...: 266423: : 338it [00:00, 673.59it/s]
# Decoding masks...: 267448: : 338it [00:00, 673.59it/s]
# Decoding masks...: 267448: : 402it [00:00, 662.03it/s]
# Decoding masks...: 268473: : 402it [00:00, 662.03it/s]
# Decoding masks...: 269498: : 402it [00:00, 662.03it/s]
# Decoding masks...: 269545: : 402it [00:00, 662.03it/s]
# Decoding masks...: 270523: : 402it [00:00, 662.03it/s]
# Decoding masks...: 270570: : 402it [00:00, 662.03it/s]
# Decoding masks...: 271596: : 402it [00:00, 662.03it/s]
# Decoding masks...: 272621: : 402it [00:00, 662.03it/s]
# Decoding masks...: 273647: : 402it [00:00, 662.03it/s]
# Decoding masks...: 274672: : 402it [00:00, 662.03it/s]
# Decoding masks...: 275698: : 402it [00:00, 662.03it/s]
# Decoding masks...: 276723: : 402it [00:00, 662.03it/s]
# Decoding masks...: 277745: : 402it [00:00, 662.03it/s]
# Decoding masks...: 278763: : 402it [00:00, 662.03it/s]
# Decoding masks...: 279783: : 402it [00:00, 662.03it/s]
# Decoding masks...: 280805: : 402it [00:00, 662.03it/s]
# Decoding masks...: 281828: : 402it [00:00, 662.03it/s]
# Decoding masks...: 282850: : 402it [00:00, 662.03it/s]
# Decoding masks...: 283872: : 402it [00:00, 662.03it/s]
# Decoding masks...: 284894: : 402it [00:00, 662.03it/s]
# Decoding masks...: 285917: : 402it [00:00, 662.03it/s]
# Decoding masks...: 286939: : 402it [00:00, 662.03it/s]
# Decoding masks...: 287960: : 402it [00:00, 662.03it/s]
# Decoding masks...: 288981: : 402it [00:00, 662.03it/s]
# Decoding masks...: 290002: : 402it [00:00, 662.03it/s]
# Decoding masks...: 291023: : 402it [00:00, 662.03it/s]
# Decoding masks...: 292043: : 402it [00:00, 662.03it/s]
# Decoding masks...: 293061: : 402it [00:00, 662.03it/s]
# Decoding masks...: 294080: : 402it [00:00, 662.03it/s]
# Decoding masks...: 295039: : 402it [00:00, 662.03it/s]
# Decoding masks...: 295100: : 402it [00:00, 662.03it/s]
# Decoding masks...: 296063: : 402it [00:00, 662.03it/s]
# Decoding masks...: 296120: : 402it [00:00, 662.03it/s]
# Decoding masks...: 296344: : 402it [00:00, 662.03it/s]
# Decoding masks...: 297088: : 402it [00:00, 662.03it/s]
# Decoding masks...: 297139: : 402it [00:00, 662.03it/s]
# Decoding masks...: 297375: : 402it [00:00, 662.03it/s]
# Decoding masks...: 298112: : 402it [00:00, 662.03it/s]
# Decoding masks...: 298159: : 402it [00:00, 662.03it/s]
# Decoding masks...: 298402: : 402it [00:00, 662.03it/s]
# Decoding masks...: 299136: : 402it [00:00, 662.03it/s]
# Decoding masks...: 299179: : 402it [00:00, 662.03it/s]
# Decoding masks...: 299426: : 402it [00:00, 662.03it/s]
# Decoding masks...: 300160: : 402it [00:00, 662.03it/s]
# Decoding masks...: 300199: : 402it [00:00, 662.03it/s]
# Decoding masks...: 300450: : 402it [00:00, 662.03it/s]
# Decoding masks...: 301184: : 402it [00:00, 662.03it/s]
# Decoding masks...: 301473: : 402it [00:00, 662.03it/s]
# Decoding masks...: 302209: : 402it [00:00, 662.03it/s]
# Decoding masks...: 302497: : 402it [00:00, 662.03it/s]
# Decoding masks...: 303233: : 402it [00:00, 662.03it/s]
# Decoding masks...: 303521: : 402it [00:00, 662.03it/s]
# Decoding masks...: 304258: : 402it [00:00, 662.03it/s]
# Decoding masks...: 304545: : 402it [00:00, 662.03it/s]
# Decoding masks...: 304552: : 402it [00:00, 662.03it/s]
# Decoding masks...: 305283: : 402it [00:00, 662.03it/s]
# Decoding masks...: 305569: : 402it [00:00, 662.03it/s]
# Decoding masks...: 305577: : 402it [00:00, 662.03it/s]
# Decoding masks...: 306308: : 402it [00:00, 662.03it/s]
# Decoding masks...: 306593: : 402it [00:00, 662.03it/s]
# Decoding masks...: 306601: : 402it [00:00, 662.03it/s]
# Decoding masks...: 307333: : 402it [00:00, 662.03it/s]
# Decoding masks...: 307617: : 402it [00:00, 662.03it/s]
# Decoding masks...: 307626: : 402it [00:00, 662.03it/s]
# Decoding masks...: 308358: : 402it [00:00, 662.03it/s]
# Decoding masks...: 308640: : 402it [00:00, 662.03it/s]
# Decoding masks...: 308650: : 402it [00:00, 662.03it/s]
# Decoding masks...: 309384: : 402it [00:00, 662.03it/s]
# Decoding masks...: 309664: : 402it [00:00, 662.03it/s]
# Decoding masks...: 309675: : 402it [00:00, 662.03it/s]
# Decoding masks...: 309675: : 471it [00:00, 666.83it/s]
# Decoding masks...: 310409: : 471it [00:00, 666.83it/s]
# Decoding masks...: 310688: : 471it [00:00, 666.83it/s]
# Decoding masks...: 310699: : 471it [00:00, 666.83it/s]
# Decoding masks...: 311434: : 471it [00:00, 666.83it/s]
# Decoding masks...: 311712: : 471it [00:00, 666.83it/s]
# Decoding masks...: 311723: : 471it [00:00, 666.83it/s]
# Decoding masks...: 312459: : 471it [00:00, 666.83it/s]
# Decoding masks...: 312736: : 471it [00:00, 666.83it/s]
# Decoding masks...: 312747: : 471it [00:00, 666.83it/s]
# Decoding masks...: 313485: : 471it [00:00, 666.83it/s]
# Decoding masks...: 313760: : 471it [00:00, 666.83it/s]
# Decoding masks...: 313771: : 471it [00:00, 666.83it/s]
# Decoding masks...: 314510: : 471it [00:00, 666.83it/s]
# Decoding masks...: 314784: : 471it [00:00, 666.83it/s]
# Decoding masks...: 314795: : 471it [00:00, 666.83it/s]
# Decoding masks...: 315535: : 471it [00:00, 666.83it/s]
# Decoding masks...: 315807: : 471it [00:00, 666.83it/s]
# Decoding masks...: 315819: : 471it [00:00, 666.83it/s]
# Decoding masks...: 316560: : 471it [00:00, 666.83it/s]
# Decoding masks...: 316831: : 471it [00:00, 666.83it/s]
# Decoding masks...: 316843: : 471it [00:00, 666.83it/s]
# Decoding masks...: 317586: : 471it [00:00, 666.83it/s]
# Decoding masks...: 317855: : 471it [00:00, 666.83it/s]
# Decoding masks...: 317867: : 471it [00:00, 666.83it/s]
# Decoding masks...: 318611: : 471it [00:00, 666.83it/s]
# Decoding masks...: 318879: : 471it [00:00, 666.83it/s]
# Decoding masks...: 318891: : 471it [00:00, 666.83it/s]
# Decoding masks...: 319636: : 471it [00:00, 666.83it/s]
# Decoding masks...: 319903: : 471it [00:00, 666.83it/s]
# Decoding masks...: 319915: : 471it [00:00, 666.83it/s]
# Decoding masks...: 320662: : 471it [00:00, 666.83it/s]
# Decoding masks...: 320927: : 471it [00:00, 666.83it/s]
# Decoding masks...: 320939: : 471it [00:00, 666.83it/s]
# Decoding masks...: 321687: : 471it [00:00, 666.83it/s]
# Decoding masks...: 321952: : 471it [00:00, 666.83it/s]
# Decoding masks...: 321963: : 471it [00:00, 666.83it/s]
# Decoding masks...: 322713: : 471it [00:00, 666.83it/s]
# Decoding masks...: 322976: : 471it [00:00, 666.83it/s]
# Decoding masks...: 322987: : 471it [00:00, 666.83it/s]
# Decoding masks...: 323738: : 471it [00:00, 666.83it/s]
# Decoding masks...: 324000: : 471it [00:00, 666.83it/s]
# Decoding masks...: 324011: : 471it [00:00, 666.83it/s]
# Decoding masks...: 324764: : 471it [00:00, 666.83it/s]
# Decoding masks...: 325024: : 471it [00:00, 666.83it/s]
# Decoding masks...: 325035: : 471it [00:00, 666.83it/s]
# Decoding masks...: 325789: : 471it [00:00, 666.83it/s]
# Decoding masks...: 326048: : 471it [00:00, 666.83it/s]
# Decoding masks...: 326059: : 471it [00:00, 666.83it/s]
# Decoding masks...: 326813: : 471it [00:00, 666.83it/s]
# Decoding masks...: 327073: : 471it [00:00, 666.83it/s]
# Decoding masks...: 327083: : 471it [00:00, 666.83it/s]
# Decoding masks...: 327837: : 471it [00:00, 666.83it/s]
# Decoding masks...: 328097: : 471it [00:00, 666.83it/s]
# Decoding masks...: 328107: : 471it [00:00, 666.83it/s]
# Decoding masks...: 328861: : 471it [00:00, 666.83it/s]
# Decoding masks...: 329121: : 471it [00:00, 666.83it/s]
# Decoding masks...: 329131: : 471it [00:00, 666.83it/s]
# Decoding masks...: 329885: : 471it [00:00, 666.83it/s]
# Decoding masks...: 330145: : 471it [00:00, 666.83it/s]
# Decoding masks...: 330156: : 471it [00:00, 666.83it/s]
# Decoding masks...: 330908: : 471it [00:00, 666.83it/s]
# Decoding masks...: 331169: : 471it [00:00, 666.83it/s]
# Decoding masks...: 331180: : 471it [00:00, 666.83it/s]
# Decoding masks...: 331932: : 471it [00:00, 666.83it/s]
# Decoding masks...: 332204: : 471it [00:00, 666.83it/s]
# Decoding masks...: 332956: : 471it [00:00, 666.83it/s]
# Decoding masks...: 332956: : 537it [00:00, 663.21it/s]
# Decoding masks...: 333228: : 537it [00:00, 663.21it/s]
# Decoding masks...: 333980: : 537it [00:00, 663.21it/s]
# Decoding masks...: 334253: : 537it [00:00, 663.21it/s]
# Decoding masks...: 335004: : 537it [00:00, 663.21it/s]
# Decoding masks...: 335277: : 537it [00:00, 663.21it/s]
# Decoding masks...: 336028: : 537it [00:00, 663.21it/s]
# Decoding masks...: 336301: : 537it [00:00, 663.21it/s]
# Decoding masks...: 337052: : 537it [00:00, 663.21it/s]
# Decoding masks...: 337326: : 537it [00:00, 663.21it/s]
# Decoding masks...: 338076: : 537it [00:00, 663.21it/s]
# Decoding masks...: 338350: : 537it [00:00, 663.21it/s]
# Decoding masks...: 339100: : 537it [00:00, 663.21it/s]
# Decoding masks...: 339374: : 537it [00:00, 663.21it/s]
# Decoding masks...: 340124: : 537it [00:00, 663.21it/s]
# Decoding masks...: 340399: : 537it [00:00, 663.21it/s]
# Decoding masks...: 341148: : 537it [00:00, 663.21it/s]
# Decoding masks...: 341424: : 537it [00:00, 663.21it/s]
# Decoding masks...: 342172: : 537it [00:00, 663.21it/s]
# Decoding masks...: 342449: : 537it [00:00, 663.21it/s]
# Decoding masks...: 343196: : 537it [00:00, 663.21it/s]
# Decoding masks...: 343474: : 537it [00:00, 663.21it/s]
# Decoding masks...: 344220: : 537it [00:00, 663.21it/s]
# Decoding masks...: 344499: : 537it [00:00, 663.21it/s]
# Decoding masks...: 345244: : 537it [00:00, 663.21it/s]
# Decoding masks...: 345524: : 537it [00:00, 663.21it/s]
# Decoding masks...: 346268: : 537it [00:00, 663.21it/s]
# Decoding masks...: 346549: : 537it [00:00, 663.21it/s]
# Decoding masks...: 347292: : 537it [00:00, 663.21it/s]
# Decoding masks...: 347574: : 537it [00:00, 663.21it/s]
# Decoding masks...: 348316: : 537it [00:00, 663.21it/s]
# Decoding masks...: 348599: : 537it [00:00, 663.21it/s]
# Decoding masks...: 349340: : 537it [00:00, 663.21it/s]
# Decoding masks...: 349624: : 537it [00:00, 663.21it/s]
# Decoding masks...: 350365: : 537it [00:00, 663.21it/s]
# Decoding masks...: 350649: : 537it [00:00, 663.21it/s]
# Decoding masks...: 351389: : 537it [00:00, 663.21it/s]
# Decoding masks...: 351674: : 537it [00:00, 663.21it/s]
# Decoding masks...: 352413: : 537it [00:00, 663.21it/s]
# Decoding masks...: 352699: : 537it [00:00, 663.21it/s]
# Decoding masks...: 353438: : 537it [00:00, 663.21it/s]
# Decoding masks...: 353724: : 537it [00:00, 663.21it/s]
# Decoding masks...: 354462: : 537it [00:00, 663.21it/s]
# Decoding masks...: 354749: : 537it [00:00, 663.21it/s]
# Decoding masks...: 355486: : 537it [00:00, 663.21it/s]
# Decoding masks...: 355774: : 537it [00:00, 663.21it/s]
# Decoding masks...: 356510: : 537it [00:00, 663.21it/s]
# Decoding masks...: 356799: : 537it [00:00, 663.21it/s]
# Decoding masks...: 357535: : 537it [00:00, 663.21it/s]
# Decoding masks...: 357827: : 537it [00:00, 663.21it/s]
# Decoding masks...: 358559: : 537it [00:00, 663.21it/s]
# Decoding masks...: 358858: : 537it [00:00, 663.21it/s]
# Decoding masks...: 359583: : 537it [00:00, 663.21it/s]
# Decoding masks...: 359888: : 537it [00:00, 663.21it/s]
# Decoding masks...: 360608: : 537it [00:00, 663.21it/s]
# Decoding masks...: 360919: : 537it [00:00, 663.21it/s]
# Decoding masks...: 361632: : 537it [00:00, 663.21it/s]
# Decoding masks...: 361950: : 537it [00:00, 663.21it/s]
# Decoding masks...: 362656: : 537it [00:00, 663.21it/s]
# Decoding masks...: 362980: : 537it [00:00, 663.21it/s]
# Decoding masks...: 363681: : 537it [00:00, 663.21it/s]
# Decoding masks...: 364011: : 537it [00:00, 663.21it/s]
# Decoding masks...: 364705: : 537it [00:00, 663.21it/s]
# Decoding masks...: 365042: : 537it [00:00, 663.21it/s]
# Decoding masks...: 365730: : 537it [00:00, 663.21it/s]
# Decoding masks...: 365730: : 601it [00:00, 654.61it/s]
# Decoding masks...: 366072: : 601it [00:00, 654.61it/s]
# Decoding masks...: 366754: : 601it [00:00, 654.61it/s]
# Decoding masks...: 367103: : 601it [00:00, 654.61it/s]
# Decoding masks...: 367779: : 601it [00:00, 654.61it/s]
# Decoding masks...: 368134: : 601it [00:00, 654.61it/s]
# Decoding masks...: 368803: : 601it [00:00, 654.61it/s]
# Decoding masks...: 369166: : 601it [00:00, 654.61it/s]
# Decoding masks...: 369828: : 601it [00:00, 654.61it/s]
# Decoding masks...: 370200: : 601it [00:00, 654.61it/s]
# Decoding masks...: 370852: : 601it [00:00, 654.61it/s]
# Decoding masks...: 371234: : 601it [00:00, 654.61it/s]
# Decoding masks...: 371877: : 601it [00:00, 654.61it/s]
# Decoding masks...: 372268: : 601it [00:00, 654.61it/s]
# Decoding masks...: 372901: : 601it [00:00, 654.61it/s]
# Decoding masks...: 373300: : 601it [00:00, 654.61it/s]
# Decoding masks...: 373926: : 601it [00:00, 654.61it/s]
# Decoding masks...: 374330: : 601it [00:00, 654.61it/s]
# Decoding masks...: 374950: : 601it [00:00, 654.61it/s]
# Decoding masks...: 375361: : 601it [00:00, 654.61it/s]
# Decoding masks...: 375975: : 601it [00:00, 654.61it/s]
# Decoding masks...: 376391: : 601it [00:00, 654.61it/s]
# Decoding masks...: 377000: : 601it [00:00, 654.61it/s]
# Decoding masks...: 377422: : 601it [00:00, 654.61it/s]
# Decoding masks...: 378024: : 601it [00:00, 654.61it/s]
# Decoding masks...: 378452: : 601it [00:00, 654.61it/s]
# Decoding masks...: 379049: : 601it [00:00, 654.61it/s]
# Decoding masks...: 379482: : 601it [00:00, 654.61it/s]
# Decoding masks...: 380073: : 601it [00:00, 654.61it/s]
# Decoding masks...: 380513: : 601it [00:00, 654.61it/s]
# Decoding masks...: 381098: : 601it [00:00, 654.61it/s]
# Decoding masks...: 381543: : 601it [00:00, 654.61it/s]
# Decoding masks...: 382122: : 601it [00:00, 654.61it/s]
# Decoding masks...: 382574: : 601it [00:00, 654.61it/s]
# Decoding masks...: 383147: : 601it [00:00, 654.61it/s]
# Decoding masks...: 383613: : 601it [00:00, 654.61it/s]
# Decoding masks...: 384172: : 601it [00:00, 654.61it/s]
# Decoding masks...: 384660: : 601it [00:00, 654.61it/s]
# Decoding masks...: 385196: : 601it [00:00, 654.61it/s]
# Decoding masks...: 385708: : 601it [00:00, 654.61it/s]
# Decoding masks...: 386221: : 601it [00:00, 654.61it/s]
# Decoding masks...: 386745: : 601it [00:00, 654.61it/s]
# Decoding masks...: 387245: : 601it [00:00, 654.61it/s]
# Decoding masks...: 387772: : 601it [00:00, 654.61it/s]
# Decoding masks...: 388270: : 601it [00:00, 654.61it/s]
# Decoding masks...: 388799: : 601it [00:00, 654.61it/s]
# Decoding masks...: 389294: : 601it [00:00, 654.61it/s]
# Decoding masks...: 389826: : 601it [00:00, 654.61it/s]
# Decoding masks...: 390319: : 601it [00:00, 654.61it/s]
# Decoding masks...: 390853: : 601it [00:00, 654.61it/s]
# Decoding masks...: 391343: : 601it [00:00, 654.61it/s]
# Decoding masks...: 391880: : 601it [00:00, 654.61it/s]
# Decoding masks...: 392367: : 601it [00:00, 654.61it/s]
# Decoding masks...: 392906: : 601it [00:00, 654.61it/s]
# Decoding masks...: 393392: : 601it [00:00, 654.61it/s]
# Decoding masks...: 393933: : 601it [00:00, 654.61it/s]
# Decoding masks...: 394416: : 601it [00:00, 654.61it/s]
# Decoding masks...: 394960: : 601it [00:00, 654.61it/s]
# Decoding masks...: 395441: : 601it [00:00, 654.61it/s]
# Decoding masks...: 395987: : 601it [00:00, 654.61it/s]
# Decoding masks...: 396475: : 601it [00:00, 654.61it/s]
# Decoding masks...: 397014: : 601it [00:01, 654.61it/s]
# Decoding masks...: 397501: : 601it [00:01, 654.61it/s]
# Decoding masks...: 398041: : 601it [00:01, 654.61it/s]
# Decoding masks...: 398526: : 601it [00:01, 654.61it/s]
# Decoding masks...: 399067: : 601it [00:01, 654.61it/s]
# Decoding masks...: 399067: : 666it [00:01, 652.79it/s]
# Decoding masks...: 399551: : 666it [00:01, 652.79it/s]
# Decoding masks...: 400094: : 666it [00:01, 652.79it/s]
# Decoding masks...: 400576: : 666it [00:01, 652.79it/s]
# Decoding masks...: 401121: : 666it [00:01, 652.79it/s]
# Decoding masks...: 401601: : 666it [00:01, 652.79it/s]
# Decoding masks...: 402148: : 666it [00:01, 652.79it/s]
# Decoding masks...: 402626: : 666it [00:01, 652.79it/s]
# Decoding masks...: 403175: : 666it [00:01, 652.79it/s]
# Decoding masks...: 403651: : 666it [00:01, 652.79it/s]
# Decoding masks...: 404202: : 666it [00:01, 652.79it/s]
# Decoding masks...: 404677: : 666it [00:01, 652.79it/s]
# Decoding masks...: 405229: : 666it [00:01, 652.79it/s]
# Decoding masks...: 405702: : 666it [00:01, 652.79it/s]
# Decoding masks...: 406255: : 666it [00:01, 652.79it/s]
# Decoding masks...: 406727: : 666it [00:01, 652.79it/s]
# Decoding masks...: 407282: : 666it [00:01, 652.79it/s]
# Decoding masks...: 407752: : 666it [00:01, 652.79it/s]
# Decoding masks...: 408309: : 666it [00:01, 652.79it/s]
# Decoding masks...: 408777: : 666it [00:01, 652.79it/s]
# Decoding masks...: 409336: : 666it [00:01, 652.79it/s]
# Decoding masks...: 409802: : 666it [00:01, 652.79it/s]
# Decoding masks...: 410363: : 666it [00:01, 652.79it/s]
# Decoding masks...: 410827: : 666it [00:01, 652.79it/s]
# Decoding masks...: 411390: : 666it [00:01, 652.79it/s]
# Decoding masks...: 411853: : 666it [00:01, 652.79it/s]
# Decoding masks...: 412416: : 666it [00:01, 652.79it/s]
# Decoding masks...: 412878: : 666it [00:01, 652.79it/s]
# Decoding masks...: 413444: : 666it [00:01, 652.79it/s]
# Decoding masks...: 413903: : 666it [00:01, 652.79it/s]
# Decoding masks...: 414473: : 666it [00:01, 652.79it/s]
# Decoding masks...: 414928: : 666it [00:01, 652.79it/s]
# Decoding masks...: 415501: : 666it [00:01, 652.79it/s]
# Decoding masks...: 415953: : 666it [00:01, 652.79it/s]
# Decoding masks...: 416530: : 666it [00:01, 652.79it/s]
# Decoding masks...: 416978: : 666it [00:01, 652.79it/s]
# Decoding masks...: 417558: : 666it [00:01, 652.79it/s]
# Decoding masks...: 418003: : 666it [00:01, 652.79it/s]
# Decoding masks...: 418587: : 666it [00:01, 652.79it/s]
# Decoding masks...: 419029: : 666it [00:01, 652.79it/s]
# Decoding masks...: 419615: : 666it [00:01, 652.79it/s]
# Decoding masks...: 420054: : 666it [00:01, 652.79it/s]
# Decoding masks...: 420644: : 666it [00:01, 652.79it/s]
# Decoding masks...: 421079: : 666it [00:01, 652.79it/s]
# Decoding masks...: 421672: : 666it [00:01, 652.79it/s]
# Decoding masks...: 422104: : 666it [00:01, 652.79it/s]
# Decoding masks...: 422701: : 666it [00:01, 652.79it/s]
# Decoding masks...: 423129: : 666it [00:01, 652.79it/s]
# Decoding masks...: 423730: : 666it [00:01, 652.79it/s]
# Decoding masks...: 424154: : 666it [00:01, 652.79it/s]
# Decoding masks...: 424758: : 666it [00:01, 652.79it/s]
# Decoding masks...: 425179: : 666it [00:01, 652.79it/s]
# Decoding masks...: 425787: : 666it [00:01, 652.79it/s]
# Decoding masks...: 426205: : 666it [00:01, 652.79it/s]
# Decoding masks...: 426817: : 666it [00:01, 652.79it/s]
# Decoding masks...: 427230: : 666it [00:01, 652.79it/s]
# Decoding masks...: 427849: : 666it [00:01, 652.79it/s]
# Decoding masks...: 428255: : 666it [00:01, 652.79it/s]
# Decoding masks...: 428881: : 666it [00:01, 652.79it/s]
# Decoding masks...: 429280: : 666it [00:01, 652.79it/s]
# Decoding masks...: 429912: : 666it [00:01, 652.79it/s]
# Decoding masks...: 430305: : 666it [00:01, 652.79it/s]
# Decoding masks...: 430944: : 666it [00:01, 652.79it/s]
# Decoding masks...: 431330: : 666it [00:01, 652.79it/s]
# Decoding masks...: 431976: : 666it [00:01, 652.79it/s]
# Decoding masks...: 432355: : 666it [00:01, 652.79it/s]
# Decoding masks...: 432355: : 731it [00:01, 651.87it/s]
# Decoding masks...: 433008: : 731it [00:01, 651.87it/s]
# Decoding masks...: 433380: : 731it [00:01, 651.87it/s]
# Decoding masks...: 434040: : 731it [00:01, 651.87it/s]
# Decoding masks...: 434406: : 731it [00:01, 651.87it/s]
# Decoding masks...: 435072: : 731it [00:01, 651.87it/s]
# Decoding masks...: 435431: : 731it [00:01, 651.87it/s]
# Decoding masks...: 436105: : 731it [00:01, 651.87it/s]
# Decoding masks...: 436456: : 731it [00:01, 651.87it/s]
# Decoding masks...: 437138: : 731it [00:01, 651.87it/s]
# Decoding masks...: 437481: : 731it [00:01, 651.87it/s]
# Decoding masks...: 438171: : 731it [00:01, 651.87it/s]
# Decoding masks...: 438506: : 731it [00:01, 651.87it/s]
# Decoding masks...: 439531: : 731it [00:01, 651.87it/s]
# Decoding masks...: 440556: : 731it [00:01, 651.87it/s]
# Decoding masks...: 441582: : 731it [00:01, 651.87it/s]
# Decoding masks...: 442607: : 731it [00:01, 651.87it/s]
# Decoding masks...: 443632: : 731it [00:01, 651.87it/s]
# Decoding masks...: 444657: : 731it [00:01, 651.87it/s]
# Decoding masks...: 445682: : 731it [00:01, 651.87it/s]
# Decoding masks...: 446707: : 731it [00:01, 651.87it/s]
# Decoding masks...: 447732: : 731it [00:01, 651.87it/s]
# Decoding masks...: 448757: : 731it [00:01, 651.87it/s]
# Decoding masks...: 449782: : 731it [00:01, 651.87it/s]
# Decoding masks...: 450807: : 731it [00:01, 651.87it/s]
# Decoding masks...: 451833: : 731it [00:01, 651.87it/s]
# Decoding masks...: 452858: : 731it [00:01, 651.87it/s]
# Decoding masks...: 453883: : 731it [00:01, 651.87it/s]
# Decoding masks...: 454908: : 731it [00:01, 651.87it/s]
# Decoding masks...: 455933: : 731it [00:01, 651.87it/s]
# Decoding masks...: 456958: : 731it [00:01, 651.87it/s]
# Decoding masks...: 457983: : 731it [00:01, 651.87it/s]
# Decoding masks...: 459008: : 731it [00:01, 651.87it/s]
# Decoding masks...: 460033: : 731it [00:01, 651.87it/s]
# Decoding masks...: 461058: : 731it [00:01, 651.87it/s]
# Decoding masks...: 462082: : 731it [00:01, 651.87it/s]
# Decoding masks...: 463106: : 731it [00:01, 651.87it/s]
# Decoding masks...: 464130: : 731it [00:01, 651.87it/s]
# Decoding masks...: 465154: : 731it [00:01, 651.87it/s]
# Decoding masks...: 466178: : 731it [00:01, 651.87it/s]
# Decoding masks...: 467202: : 731it [00:01, 651.87it/s]
# Decoding masks...: 468226: : 731it [00:01, 651.87it/s]
# Decoding masks...: 469251: : 731it [00:01, 651.87it/s]
# Decoding masks...: 470275: : 731it [00:01, 651.87it/s]
# Decoding masks...: 471299: : 731it [00:01, 651.87it/s]
# Decoding masks...: 472323: : 731it [00:01, 651.87it/s]
# Decoding masks...: 473347: : 731it [00:01, 651.87it/s]
# Decoding masks...: 474371: : 731it [00:01, 651.87it/s]
# Decoding masks...: 475395: : 731it [00:01, 651.87it/s]
# Decoding masks...: 476419: : 731it [00:01, 651.87it/s]
# Decoding masks...: 477445: : 731it [00:01, 651.87it/s]
# Decoding masks...: 478473: : 731it [00:01, 651.87it/s]
# Decoding masks...: 479501: : 731it [00:01, 651.87it/s]
# Decoding masks...: 480529: : 731it [00:01, 651.87it/s]
# Decoding masks...: 481556: : 731it [00:01, 651.87it/s]
# Decoding masks...: 482581: : 731it [00:01, 651.87it/s]
# Decoding masks...: 483607: : 731it [00:01, 651.87it/s]
# Decoding masks...: 484632: : 731it [00:01, 651.87it/s]
# Decoding masks...: 485658: : 731it [00:01, 651.87it/s]
# Decoding masks...: 486684: : 731it [00:01, 651.87it/s]
# Decoding masks...: 487709: : 731it [00:01, 651.87it/s]
# Decoding masks...: 488735: : 731it [00:01, 651.87it/s]
# Decoding masks...: 489760: : 731it [00:01, 651.87it/s]
# Decoding masks...: 490786: : 731it [00:01, 651.87it/s]
# Decoding masks...: 491813: : 731it [00:01, 651.87it/s]
# Decoding masks...: 492841: : 731it [00:01, 651.87it/s]
# Decoding masks...: 493869: : 731it [00:01, 651.87it/s]
# Decoding masks...: 494898: : 731it [00:01, 651.87it/s]
# Decoding masks...: 495926: : 731it [00:01, 651.87it/s]
# Decoding masks...: 495926: : 799it [00:01, 658.45it/s]
# Decoding masks...: 496953: : 799it [00:01, 658.45it/s]
# Decoding masks...: 497980: : 799it [00:01, 658.45it/s]
# Decoding masks...: 499007: : 799it [00:01, 658.45it/s]
# Decoding masks...: 500034: : 799it [00:01, 658.45it/s]
# Decoding masks...: 501061: : 799it [00:01, 658.45it/s]
# Decoding masks...: 502088: : 805it [00:01, 659.93it/s]
# Loading encoded pixels...: 2: : 2it [00:01,  1.96it/s]
# 0it [00:00, ?it/s]
# Decoding masks...: 375033: : 0it [00:00, ?it/s]
# Decoding masks...: 376048: : 0it [00:00, ?it/s]
# Decoding masks...: 377062: : 0it [00:00, ?it/s]
# Decoding masks...: 378077: : 0it [00:00, ?it/s]
# Decoding masks...: 379092: : 0it [00:00, ?it/s]
# Decoding masks...: 380108: : 0it [00:00, ?it/s]
# Decoding masks...: 381127: : 0it [00:00, ?it/s]
# Decoding masks...: 382145: : 0it [00:00, ?it/s]
# Decoding masks...: 383164: : 0it [00:00, ?it/s]
# Decoding masks...: 384183: : 0it [00:00, ?it/s]
# Decoding masks...: 385203: : 0it [00:00, ?it/s]
# Decoding masks...: 386223: : 0it [00:00, ?it/s]
# Decoding masks...: 387245: : 0it [00:00, ?it/s]
# Decoding masks...: 388270: : 0it [00:00, ?it/s]
# Decoding masks...: 389294: : 0it [00:00, ?it/s]
# Decoding masks...: 390319: : 0it [00:00, ?it/s]
# Decoding masks...: 391343: : 0it [00:00, ?it/s]
# Decoding masks...: 392367: : 0it [00:00, ?it/s]
# Decoding masks...: 393392: : 0it [00:00, ?it/s]
# Decoding masks...: 394416: : 0it [00:00, ?it/s]
# Decoding masks...: 395441: : 0it [00:00, ?it/s]
# Decoding masks...: 396475: : 0it [00:00, ?it/s]
# Decoding masks...: 397501: : 0it [00:00, ?it/s]
# Decoding masks...: 398526: : 0it [00:00, ?it/s]
# Decoding masks...: 399551: : 0it [00:00, ?it/s]
# Decoding masks...: 400576: : 0it [00:00, ?it/s]
# Decoding masks...: 401601: : 0it [00:00, ?it/s]
# Decoding masks...: 402626: : 0it [00:00, ?it/s]
# Decoding masks...: 403651: : 0it [00:00, ?it/s]
# Decoding masks...: 404677: : 0it [00:00, ?it/s]
# Decoding masks...: 405702: : 0it [00:00, ?it/s]
# Decoding masks...: 406727: : 0it [00:00, ?it/s]
# Decoding masks...: 407752: : 0it [00:00, ?it/s]
# Decoding masks...: 408777: : 0it [00:00, ?it/s]
# Decoding masks...: 409802: : 0it [00:00, ?it/s]
# Decoding masks...: 410827: : 0it [00:00, ?it/s]
# Decoding masks...: 411853: : 0it [00:00, ?it/s]
# Decoding masks...: 412878: : 0it [00:00, ?it/s]
# Decoding masks...: 413903: : 0it [00:00, ?it/s]
# Decoding masks...: 414928: : 0it [00:00, ?it/s]
# Decoding masks...: 415953: : 0it [00:00, ?it/s]
# Decoding masks...: 416978: : 0it [00:00, ?it/s]
# Decoding masks...: 418003: : 0it [00:00, ?it/s]
# Decoding masks...: 419029: : 0it [00:00, ?it/s]
# Decoding masks...: 420054: : 0it [00:00, ?it/s]
# Decoding masks...: 421079: : 0it [00:00, ?it/s]
# Decoding masks...: 422104: : 0it [00:00, ?it/s]
# Decoding masks...: 423129: : 0it [00:00, ?it/s]
# Decoding masks...: 424154: : 0it [00:00, ?it/s]
# Decoding masks...: 425179: : 0it [00:00, ?it/s]
# Decoding masks...: 426205: : 0it [00:00, ?it/s]
# Decoding masks...: 427230: : 0it [00:00, ?it/s]
# Decoding masks...: 428255: : 0it [00:00, ?it/s]
# Decoding masks...: 429280: : 0it [00:00, ?it/s]
# Decoding masks...: 430305: : 0it [00:00, ?it/s]
# Decoding masks...: 431330: : 0it [00:00, ?it/s]
# Decoding masks...: 432355: : 0it [00:00, ?it/s]
# Decoding masks...: 433380: : 0it [00:00, ?it/s]
# Decoding masks...: 434406: : 0it [00:00, ?it/s]
# Decoding masks...: 435431: : 0it [00:00, ?it/s]
# Decoding masks...: 436456: : 0it [00:00, ?it/s]
# Decoding masks...: 437481: : 0it [00:00, ?it/s]
# Decoding masks...: 438506: : 0it [00:00, ?it/s]
# Decoding masks...: 439531: : 0it [00:00, ?it/s]
# Decoding masks...: 440556: : 0it [00:00, ?it/s]
# Decoding masks...: 441582: : 0it [00:00, ?it/s]
# Decoding masks...: 442607: : 0it [00:00, ?it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
target["image_id"]
# Out:
# tensor([100])

# %%
target["iscrowd"]
# Out:
# tensor([0, 0, 0, 0, 0, 0])

# %%
len(target["masks"])
# Out:
# 6

# %%
type(target["masks"][1])
# Out:
# torch.Tensor

# %%
target["class_ids"]
# Out:
# tensor([13, 10, 31, 31, 28, 23], dtype=torch.uint8)

# %%
target["boxes"]
# Out:
# tensor([[192.,   0., 300.,  52.],
#         [  0., 126., 490., 969.],
#         [366., 172., 490., 336.],
#         [  0., 165., 158., 344.],
#         [196., 126., 322., 227.],
#         [391., 915., 446., 978.]])

# %% [markdown]
# ### Display the processed data

# %%
from matplotlib.patches import Rectangle

# %matplotlib inline 
idx = 5      # _ change the number withing range 
xmin, ymin, xmax, ymax = target["boxes"][idx]

plt.imshow(img)
plt.imshow(target["masks"][idx], alpha=0.7)

plt.gca().add_patch(Rectangle((xmin,ymin),xmax-xmin  , ymax-ymin, linewidth=1,edgecolor='r',facecolor='none'))

# %%
torch.tensor([1])
